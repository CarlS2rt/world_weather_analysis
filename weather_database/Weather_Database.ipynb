# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import time
from datetime import datetime


# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
import pprint as pp

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 770

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
#set timer
start=time.perf_counter()

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date, 
                          'Weather Description': weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")

stop=time.perf_counter()
print(f'Loop took {stop - start:0.2f} seconds to complete.')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | acapulco
# Processing Record 3 of Set 1 | tasiilaq
# Processing Record 4 of Set 1 | cape town
# Processing Record 5 of Set 1 | hakvik
# City not found. Skipping...
# Processing Record 6 of Set 1 | codrington
# Processing Record 7 of Set 1 | arraial do cabo
# Processing Record 8 of Set 1 | gobabis
# Processing Record 9 of Set 1 | mareeba
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | veraval
# Processing Record 12 of Set 1 | ondjiva
# Processing Record 13 of Set 1 | tabukiniberu
# City not found. Skipping...
# Processing Record 14 of Set 1 | pitimbu
# Processing Record 15 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 16 of Set 1 | san pedro
# Processing Record 17 of Set 1 | alibag
# Processing Record 18 of Set 1 | severo-kurilsk
# Processing Record 19 of Set 1 | qaanaaq
# Processing Record 20 of Set 1 | villa carlos paz
# Processing Record 21 of Set 1 | hobart
# Processing Record 22 of Set 1 | margate
# Processing Record 23 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 24 of Set 1 | copiapo
# Processing Record 25 of Set 1 | campbell river
# Processing Record 26 of Set 1 | usinsk
# Processing Record 27 of Set 1 | cap malheureux
# Processing Record 28 of Set 1 | merrill
# Processing Record 29 of Set 1 | tarpon springs
# Processing Record 30 of Set 1 | albany
# Processing Record 31 of Set 1 | yellowknife
# Processing Record 32 of Set 1 | sug-aksy
# City not found. Skipping...
# Processing Record 33 of Set 1 | upernavik
# Processing Record 34 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 1 | tuktoyaktuk
# Processing Record 36 of Set 1 | punta arenas
# Processing Record 37 of Set 1 | taboga
# Processing Record 38 of Set 1 | naliya
# Processing Record 39 of Set 1 | ibra
# Processing Record 40 of Set 1 | khandyga
# Processing Record 41 of Set 1 | hithadhoo
# Processing Record 42 of Set 1 | victoria
# Processing Record 43 of Set 1 | auki
# Processing Record 44 of Set 1 | keti bandar
# Processing Record 45 of Set 1 | lompoc
# Processing Record 46 of Set 1 | dunmore east
# Processing Record 47 of Set 1 | alberdi
# Processing Record 48 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 1 | bengkulu
# Processing Record 50 of Set 1 | thompson
# Processing Record 1 of Set 2 | mamlyutka
# Processing Record 2 of Set 2 | pasighat
# Processing Record 3 of Set 2 | hilo
# Processing Record 4 of Set 2 | kaitangata
# Processing Record 5 of Set 2 | vestmannaeyjar
# Processing Record 6 of Set 2 | flin flon
# Processing Record 7 of Set 2 | srednekolymsk
# Processing Record 8 of Set 2 | bredasdorp
# Processing Record 9 of Set 2 | luderitz
# Processing Record 10 of Set 2 | mataura
# Processing Record 11 of Set 2 | coquimbo
# Processing Record 12 of Set 2 | ilulissat
# Processing Record 13 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 15 of Set 2 | rolim de moura
# City not found. Skipping...
# Processing Record 16 of Set 2 | barrow
# Processing Record 17 of Set 2 | kazachinskoye
# Processing Record 18 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 2 | busselton
# Processing Record 20 of Set 2 | georgetown
# Processing Record 21 of Set 2 | mount isa
# Processing Record 22 of Set 2 | narsaq
# Processing Record 23 of Set 2 | horqueta
# Processing Record 24 of Set 2 | khatanga
# Processing Record 25 of Set 2 | san patricio
# Processing Record 26 of Set 2 | tawang
# Processing Record 27 of Set 2 | tulnici
# Processing Record 28 of Set 2 | carnarvon
# Processing Record 29 of Set 2 | mar del plata
# Processing Record 30 of Set 2 | ushuaia
# Processing Record 31 of Set 2 | portland
# Processing Record 32 of Set 2 | palaiokhora
# City not found. Skipping...
# Processing Record 33 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 2 | chapais
# Processing Record 35 of Set 2 | komsomolskiy
# Processing Record 36 of Set 2 | muscat
# Processing Record 37 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 38 of Set 2 | saskylakh
# Processing Record 39 of Set 2 | byron bay
# Processing Record 40 of Set 2 | jacareacanga
# Processing Record 41 of Set 2 | new norfolk
# Processing Record 42 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 2 | hambantota
# Processing Record 45 of Set 2 | port blair
# Processing Record 46 of Set 2 | vaini
# Processing Record 47 of Set 2 | clyde river
# Processing Record 48 of Set 2 | hamilton
# Processing Record 49 of Set 2 | grand gaube
# Processing Record 50 of Set 2 | berlevag
# Processing Record 1 of Set 3 | cidreira
# Processing Record 2 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 3 | bontang
# Processing Record 4 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 3 | sidi ali
# Processing Record 6 of Set 3 | port alfred
# Processing Record 7 of Set 3 | semnan
# Processing Record 8 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 3 | cabo san lucas
# Processing Record 10 of Set 3 | paka
# Processing Record 11 of Set 3 | saldanha
# Processing Record 12 of Set 3 | bukama
# Processing Record 13 of Set 3 | egvekinot
# Processing Record 14 of Set 3 | mbini
# Processing Record 15 of Set 3 | langsa
# Processing Record 16 of Set 3 | belyy yar
# Processing Record 17 of Set 3 | kinablangan
# Processing Record 18 of Set 3 | inuvik
# Processing Record 19 of Set 3 | aklavik
# Processing Record 20 of Set 3 | imeni stepana razina
# Processing Record 21 of Set 3 | provideniya
# Processing Record 22 of Set 3 | castro
# Processing Record 23 of Set 3 | pevek
# Processing Record 24 of Set 3 | nemuro
# Processing Record 25 of Set 3 | bluff
# Processing Record 26 of Set 3 | strezhevoy
# Processing Record 27 of Set 3 | itagiba
# Processing Record 28 of Set 3 | utiroa
# City not found. Skipping...
# Processing Record 29 of Set 3 | lagos
# Processing Record 30 of Set 3 | isangel
# Processing Record 31 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 3 | kavieng
# Processing Record 33 of Set 3 | umm kaddadah
# Processing Record 34 of Set 3 | puerto ayora
# Processing Record 35 of Set 3 | lebu
# Processing Record 36 of Set 3 | laguna
# Processing Record 37 of Set 3 | ribeira grande
# Processing Record 38 of Set 3 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 39 of Set 3 | straldza
# City not found. Skipping...
# Processing Record 40 of Set 3 | iqaluit
# Processing Record 41 of Set 3 | butaritari
# Processing Record 42 of Set 3 | kloulklubed
# Processing Record 43 of Set 3 | bilma
# Processing Record 44 of Set 3 | taburi
# City not found. Skipping...
# Processing Record 45 of Set 3 | norman wells
# Processing Record 46 of Set 3 | souillac
# Processing Record 47 of Set 3 | ban nahin
# Processing Record 48 of Set 3 | longyearbyen
# Processing Record 49 of Set 3 | avarua
# Processing Record 50 of Set 3 | puerto quijarro
# Processing Record 1 of Set 4 | pervomayskoye
# Processing Record 2 of Set 4 | san rafael
# Processing Record 3 of Set 4 | taltal
# Processing Record 4 of Set 4 | champerico
# Processing Record 5 of Set 4 | mokolo
# Processing Record 6 of Set 4 | gayny
# Processing Record 7 of Set 4 | quatre cocos
# Processing Record 8 of Set 4 | roslyakovo
# Processing Record 9 of Set 4 | tahe
# Processing Record 10 of Set 4 | saint george
# Processing Record 11 of Set 4 | te anau
# Processing Record 12 of Set 4 | chicama
# Processing Record 13 of Set 4 | sitka
# Processing Record 14 of Set 4 | akhmeta
# Processing Record 15 of Set 4 | buqayq
# City not found. Skipping...
# Processing Record 16 of Set 4 | marawi
# Processing Record 17 of Set 4 | atuona
# Processing Record 18 of Set 4 | kapaa
# Processing Record 19 of Set 4 | murmashi
# Processing Record 20 of Set 4 | chuy
# Processing Record 21 of Set 4 | comodoro rivadavia
# Processing Record 22 of Set 4 | maragogi
# Processing Record 23 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 4 | batemans bay
# Processing Record 25 of Set 4 | suntar
# Processing Record 26 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 27 of Set 4 | san luis
# Processing Record 28 of Set 4 | asyut
# Processing Record 29 of Set 4 | urdoma
# Processing Record 30 of Set 4 | jinchang
# Processing Record 31 of Set 4 | beringovskiy
# Processing Record 32 of Set 4 | hobyo
# Processing Record 33 of Set 4 | saint-philippe
# Processing Record 34 of Set 4 | necochea
# Processing Record 35 of Set 4 | santo antonio do ica
# Processing Record 36 of Set 4 | marshall
# Processing Record 37 of Set 4 | sao cristovao
# Processing Record 38 of Set 4 | ende
# Processing Record 39 of Set 4 | mehamn
# Processing Record 40 of Set 4 | auch
# Processing Record 41 of Set 4 | santa lucia
# Processing Record 42 of Set 4 | kupino
# Processing Record 43 of Set 4 | nakamura
# Processing Record 44 of Set 4 | jamestown
# Processing Record 45 of Set 4 | vila franca do campo
# Processing Record 46 of Set 4 | bend
# Processing Record 47 of Set 4 | borogontsy
# Processing Record 48 of Set 4 | pangai
# Processing Record 49 of Set 4 | pokaran
# Processing Record 50 of Set 4 | mildura
# Processing Record 1 of Set 5 | hasaki
# Processing Record 2 of Set 5 | port-gentil
# Processing Record 3 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 5 | touros
# Processing Record 5 of Set 5 | okhotsk
# Processing Record 6 of Set 5 | rawson
# Processing Record 7 of Set 5 | greenwood
# Processing Record 8 of Set 5 | am timan
# Processing Record 9 of Set 5 | goderich
# Processing Record 10 of Set 5 | bambous virieux
# Processing Record 11 of Set 5 | vardo
# Processing Record 12 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 13 of Set 5 | ponta do sol
# Processing Record 14 of Set 5 | lalomanu
# City not found. Skipping...
# Processing Record 15 of Set 5 | marsa matruh
# Processing Record 16 of Set 5 | emerald
# Processing Record 17 of Set 5 | goroka
# Processing Record 18 of Set 5 | kodiak
# Processing Record 19 of Set 5 | east london
# Processing Record 20 of Set 5 | port elizabeth
# Processing Record 21 of Set 5 | dikson
# Processing Record 22 of Set 5 | zhanatas
# City not found. Skipping...
# Processing Record 23 of Set 5 | sarangani
# Processing Record 24 of Set 5 | darnah
# Processing Record 25 of Set 5 | vao
# Processing Record 26 of Set 5 | atoyac
# Processing Record 27 of Set 5 | kashi
# Processing Record 28 of Set 5 | kachikau
# City not found. Skipping...
# Processing Record 29 of Set 5 | sao sepe
# Processing Record 30 of Set 5 | mutsamudu
# City not found. Skipping...
# Processing Record 31 of Set 5 | havelock
# Processing Record 32 of Set 5 | yangcun
# Processing Record 33 of Set 5 | namibe
# Processing Record 34 of Set 5 | staryy nadym
# Processing Record 35 of Set 5 | namtsy
# Processing Record 36 of Set 5 | nikolskoye
# Processing Record 37 of Set 5 | bubaque
# Processing Record 38 of Set 5 | dicabisagan
# Processing Record 39 of Set 5 | hit
# Processing Record 40 of Set 5 | hoi an
# Processing Record 41 of Set 5 | talnakh
# Processing Record 42 of Set 5 | svetlogorsk
# Processing Record 43 of Set 5 | springbok
# Processing Record 44 of Set 5 | lavrentiya
# Processing Record 45 of Set 5 | sabha
# Processing Record 46 of Set 5 | dingle
# Processing Record 47 of Set 5 | marsh harbour
# Processing Record 48 of Set 5 | mahebourg
# Processing Record 49 of Set 5 | burnie
# Processing Record 50 of Set 5 | abay
# Processing Record 1 of Set 6 | monatele
# City not found. Skipping...
# Processing Record 2 of Set 6 | fairview
# Processing Record 3 of Set 6 | pangnirtung
# Processing Record 4 of Set 6 | anadyr
# Processing Record 5 of Set 6 | wicklow
# Processing Record 6 of Set 6 | moba
# Processing Record 7 of Set 6 | caernarfon
# Processing Record 8 of Set 6 | kibre mengist
# Processing Record 9 of Set 6 | geraldton
# Processing Record 10 of Set 6 | inta
# Processing Record 11 of Set 6 | yulara
# Processing Record 12 of Set 6 | rapid valley
# Processing Record 13 of Set 6 | sungairaya
# Processing Record 14 of Set 6 | sao filipe
# Processing Record 15 of Set 6 | mao
# Processing Record 16 of Set 6 | tottori
# Processing Record 17 of Set 6 | erenhot
# Processing Record 18 of Set 6 | agadez
# Processing Record 19 of Set 6 | kavaratti
# Processing Record 20 of Set 6 | maniitsoq
# Processing Record 21 of Set 6 | la asuncion
# Processing Record 22 of Set 6 | sherghati
# Processing Record 23 of Set 6 | shubarshi
# Processing Record 24 of Set 6 | christchurch
# Processing Record 25 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 6 | lensk
# Processing Record 27 of Set 6 | faanui
# Processing Record 28 of Set 6 | oruro
# Processing Record 29 of Set 6 | xai-xai
# Processing Record 30 of Set 6 | yar-sale
# Processing Record 31 of Set 6 | nisia floresta
# Processing Record 32 of Set 6 | alyangula
# Processing Record 33 of Set 6 | tanete
# Processing Record 34 of Set 6 | stornoway
# Processing Record 35 of Set 6 | kutum
# Processing Record 36 of Set 6 | odienne
# Processing Record 37 of Set 6 | buluang
# Processing Record 38 of Set 6 | vernon
# Processing Record 39 of Set 6 | bethel
# Processing Record 40 of Set 6 | maltahohe
# Processing Record 41 of Set 6 | pionerskiy
# Processing Record 42 of Set 6 | saint-francois
# Processing Record 43 of Set 6 | ostrovnoy
# Processing Record 44 of Set 6 | zhaozhou
# Processing Record 45 of Set 6 | jiuquan
# Processing Record 46 of Set 6 | oistins
# Processing Record 47 of Set 6 | kokopo
# Processing Record 48 of Set 6 | salisbury
# Processing Record 49 of Set 6 | yirol
# City not found. Skipping...
# Processing Record 50 of Set 6 | coihaique
# Processing Record 1 of Set 7 | kushima
# Processing Record 2 of Set 7 | fairbanks
# Processing Record 3 of Set 7 | shirokiy
# Processing Record 4 of Set 7 | shimoda
# Processing Record 5 of Set 7 | palembang
# Processing Record 6 of Set 7 | arlit
# Processing Record 7 of Set 7 | hervey bay
# Processing Record 8 of Set 7 | deputatskiy
# Processing Record 9 of Set 7 | palestine
# Processing Record 10 of Set 7 | airai
# Processing Record 11 of Set 7 | linxia
# Processing Record 12 of Set 7 | samarai
# Processing Record 13 of Set 7 | golden
# Processing Record 14 of Set 7 | prince rupert
# Processing Record 15 of Set 7 | arman
# Processing Record 16 of Set 7 | yima
# Processing Record 17 of Set 7 | stawell
# Processing Record 18 of Set 7 | skowhegan
# Processing Record 19 of Set 7 | mocambique
# City not found. Skipping...
# Processing Record 20 of Set 7 | urengoy
# Processing Record 21 of Set 7 | mazagao
# Processing Record 22 of Set 7 | harstad
# Processing Record 23 of Set 7 | chenove
# Processing Record 24 of Set 7 | sedro-woolley
# Processing Record 25 of Set 7 | gamba
# Processing Record 26 of Set 7 | bedford
# Processing Record 27 of Set 7 | oriximina
# Processing Record 28 of Set 7 | praia da vitoria
# Processing Record 29 of Set 7 | pachino
# Processing Record 30 of Set 7 | rongcheng
# Processing Record 31 of Set 7 | bandarbeyla
# Processing Record 32 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 33 of Set 7 | vastervik
# City not found. Skipping...
# Processing Record 34 of Set 7 | saint-augustin
# Processing Record 35 of Set 7 | lagoa
# Processing Record 36 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 7 | chuguyevka
# Processing Record 38 of Set 7 | chillicothe
# Processing Record 39 of Set 7 | bundaberg
# Processing Record 40 of Set 7 | jimo
# Processing Record 41 of Set 7 | lodwar
# Processing Record 42 of Set 7 | port hawkesbury
# Processing Record 43 of Set 7 | tual
# Processing Record 44 of Set 7 | bayonet point
# Processing Record 45 of Set 7 | severodvinsk
# Processing Record 46 of Set 7 | donegal
# Processing Record 47 of Set 7 | tasbuget
# City not found. Skipping...
# Processing Record 48 of Set 7 | darhan
# Processing Record 49 of Set 7 | fort nelson
# Processing Record 50 of Set 7 | pyaozerskiy
# Processing Record 1 of Set 8 | camalu
# Processing Record 2 of Set 8 | igrim
# Processing Record 3 of Set 8 | yangambi
# Processing Record 4 of Set 8 | atherton
# Processing Record 5 of Set 8 | tigil
# Processing Record 6 of Set 8 | pacific grove
# Processing Record 7 of Set 8 | sao joao da barra
# Processing Record 8 of Set 8 | booue
# Processing Record 9 of Set 8 | roma
# Processing Record 10 of Set 8 | novoagansk
# Processing Record 11 of Set 8 | tura
# Processing Record 12 of Set 8 | juwana
# Processing Record 13 of Set 8 | fianarantsoa
# Processing Record 14 of Set 8 | suzu
# City not found. Skipping...
# Processing Record 15 of Set 8 | harper
# Processing Record 16 of Set 8 | rio grande
# Processing Record 17 of Set 8 | husavik
# Processing Record 18 of Set 8 | niquero
# Processing Record 19 of Set 8 | wanning
# Processing Record 20 of Set 8 | kikwit
# Processing Record 21 of Set 8 | andrelandia
# Processing Record 22 of Set 8 | meihekou
# Processing Record 23 of Set 8 | los llanos de aridane
# Processing Record 24 of Set 8 | diamantino
# Processing Record 25 of Set 8 | qasigiannguit
# Processing Record 26 of Set 8 | puerto narino
# Processing Record 27 of Set 8 | adrar
# Processing Record 28 of Set 8 | piney green
# Processing Record 29 of Set 8 | asekeyevo
# Processing Record 30 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 31 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 32 of Set 8 | port macquarie
# Processing Record 33 of Set 8 | lahij
# Processing Record 34 of Set 8 | tautira
# Processing Record 35 of Set 8 | itarema
# Processing Record 36 of Set 8 | jensen beach
# Processing Record 37 of Set 8 | nelson bay
# Processing Record 38 of Set 8 | pingxiang
# Processing Record 39 of Set 8 | cayenne
# Processing Record 40 of Set 8 | ormstown
# Processing Record 41 of Set 8 | hovd
# Processing Record 42 of Set 8 | joensuu
# Processing Record 43 of Set 8 | hofn
# Processing Record 44 of Set 8 | iwanai
# Processing Record 45 of Set 8 | grindavik
# Processing Record 46 of Set 8 | esperance
# Processing Record 47 of Set 8 | brive-la-gaillarde
# Processing Record 48 of Set 8 | douentza
# Processing Record 49 of Set 8 | waipawa
# Processing Record 50 of Set 8 | nizwa
# Processing Record 1 of Set 9 | adwa
# Processing Record 2 of Set 9 | caxito
# Processing Record 3 of Set 9 | baykit
# Processing Record 4 of Set 9 | atasu
# Processing Record 5 of Set 9 | stepnyak
# Processing Record 6 of Set 9 | leningradskiy
# Processing Record 7 of Set 9 | libertador general san martin
# Processing Record 8 of Set 9 | antofagasta
# Processing Record 9 of Set 9 | svecha
# Processing Record 10 of Set 9 | saint-pierre
# Processing Record 11 of Set 9 | port keats
# Processing Record 12 of Set 9 | broome
# Processing Record 13 of Set 9 | trelew
# Processing Record 14 of Set 9 | kegayli
# City not found. Skipping...
# Processing Record 15 of Set 9 | babushkin
# Processing Record 16 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 17 of Set 9 | newport
# Processing Record 18 of Set 9 | pemangkat
# Processing Record 19 of Set 9 | aksu
# Processing Record 20 of Set 9 | xining
# Processing Record 21 of Set 9 | boston
# Processing Record 22 of Set 9 | sitrah
# Processing Record 23 of Set 9 | hirakud
# Processing Record 24 of Set 9 | ginir
# Processing Record 25 of Set 9 | penha
# Processing Record 26 of Set 9 | gohpur
# Processing Record 27 of Set 9 | nanakuli
# Processing Record 28 of Set 9 | kysyl-syr
# Processing Record 29 of Set 9 | eldama ravine
# Processing Record 30 of Set 9 | pombia
# Processing Record 31 of Set 9 | bikaner
# Processing Record 32 of Set 9 | sioux lookout
# Processing Record 33 of Set 9 | muros
# Processing Record 34 of Set 9 | hirara
# Processing Record 35 of Set 9 | kyzyl-suu
# Processing Record 36 of Set 9 | namatanai
# Processing Record 37 of Set 9 | andros town
# Processing Record 38 of Set 9 | warrnambool
# Processing Record 39 of Set 9 | henties bay
# Processing Record 40 of Set 9 | shellbrook
# Processing Record 41 of Set 9 | kamensk-uralskiy
# Processing Record 42 of Set 9 | korgen
# Processing Record 43 of Set 9 | nome
# Processing Record 44 of Set 9 | gaziantep
# Processing Record 45 of Set 9 | aztec
# Processing Record 46 of Set 9 | tubruq
# City not found. Skipping...
# Processing Record 47 of Set 9 | vanimo
# Processing Record 48 of Set 9 | ulladulla
# Processing Record 49 of Set 9 | rockhampton
# Processing Record 50 of Set 9 | nola
# Processing Record 1 of Set 10 | panjab
# Processing Record 2 of Set 10 | sri aman
# Processing Record 3 of Set 10 | klyuchi
# Processing Record 4 of Set 10 | tacuarembo
# Processing Record 5 of Set 10 | sembe
# Processing Record 6 of Set 10 | sovetskiy
# Processing Record 7 of Set 10 | katsuura
# Processing Record 8 of Set 10 | manokwari
# Processing Record 9 of Set 10 | olinda
# Processing Record 10 of Set 10 | krasnoye
# Processing Record 11 of Set 10 | fortuna
# Processing Record 12 of Set 10 | haines junction
# Processing Record 13 of Set 10 | khurai
# Processing Record 14 of Set 10 | nampula
# Processing Record 15 of Set 10 | ransang
# Processing Record 16 of Set 10 | flinders
# Processing Record 17 of Set 10 | caranan
# Processing Record 18 of Set 10 | lazaro cardenas
# Processing Record 19 of Set 10 | shache
# Processing Record 20 of Set 10 | kokorevka
# Processing Record 21 of Set 10 | ayan
# Processing Record 22 of Set 10 | okato
# Processing Record 23 of Set 10 | springdale
# Processing Record 24 of Set 10 | tiznit
# Processing Record 25 of Set 10 | kruisfontein
# Processing Record 26 of Set 10 | tarko-sale
# Processing Record 27 of Set 10 | terrace
# Processing Record 28 of Set 10 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 29 of Set 10 | borba
# Processing Record 30 of Set 10 | skelleftea
# Processing Record 31 of Set 10 | noumea
# Processing Record 32 of Set 10 | hualmay
# Processing Record 33 of Set 10 | oktyabrskiy
# Processing Record 34 of Set 10 | sorland
# Processing Record 35 of Set 10 | sola
# Processing Record 36 of Set 10 | gweta
# Processing Record 37 of Set 10 | mayor pablo lagerenza
# Processing Record 38 of Set 10 | uruacu
# Processing Record 39 of Set 10 | zhigalovo
# Processing Record 40 of Set 10 | hasanabad
# Processing Record 41 of Set 10 | mogadishu
# Processing Record 42 of Set 10 | manado
# Processing Record 43 of Set 10 | honiara
# Processing Record 44 of Set 10 | saint-joseph
# Processing Record 45 of Set 10 | vila velha
# Processing Record 46 of Set 10 | kerteh
# City not found. Skipping...
# Processing Record 47 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 48 of Set 10 | antalaha
# Processing Record 49 of Set 10 | lola
# Processing Record 50 of Set 10 | caravelas
# Processing Record 1 of Set 11 | suao
# City not found. Skipping...
# Processing Record 2 of Set 11 | tiksi
# Processing Record 3 of Set 11 | naze
# Processing Record 4 of Set 11 | moree
# Processing Record 5 of Set 11 | iwaki
# Processing Record 6 of Set 11 | port hardy
# Processing Record 7 of Set 11 | nanortalik
# Processing Record 8 of Set 11 | avera
# Processing Record 9 of Set 11 | ous
# Processing Record 10 of Set 11 | coolum beach
# Processing Record 11 of Set 11 | phonhong
# Processing Record 12 of Set 11 | taonan
# Processing Record 13 of Set 11 | kjollefjord
# Processing Record 14 of Set 11 | lasa
# Processing Record 15 of Set 11 | ksenyevka
# City not found. Skipping...
# Processing Record 16 of Set 11 | dali
# Processing Record 17 of Set 11 | taoudenni
# Processing Record 18 of Set 11 | herat
# Processing Record 19 of Set 11 | tobol
# Processing Record 20 of Set 11 | hermosillo
# Processing Record 21 of Set 11 | sechura
# Processing Record 22 of Set 11 | mocuba
# Processing Record 23 of Set 11 | pisco
# Processing Record 24 of Set 11 | kenora
# Processing Record 25 of Set 11 | santa rosa
# Processing Record 26 of Set 11 | wakkanai
# Processing Record 27 of Set 11 | mergui
# City not found. Skipping...
# Processing Record 28 of Set 11 | neuquen
# Processing Record 29 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 30 of Set 11 | monrovia
# Processing Record 31 of Set 11 | evensk
# Processing Record 32 of Set 11 | xuddur
# Processing Record 33 of Set 11 | manjacaze
# Processing Record 34 of Set 11 | palmer
# Processing Record 35 of Set 11 | jiwani
# Processing Record 36 of Set 11 | olden
# Processing Record 37 of Set 11 | skjervoy
# Processing Record 38 of Set 11 | slave lake
# Processing Record 39 of Set 11 | dimapur
# Processing Record 40 of Set 11 | khokhlovo
# Processing Record 41 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 43 of Set 11 | juneau
# Processing Record 44 of Set 11 | phetchaburi
# Processing Record 45 of Set 11 | cap-haitien
# Processing Record 46 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 47 of Set 11 | ancud
# Processing Record 48 of Set 11 | salalah
# Processing Record 49 of Set 11 | ambon
# Processing Record 50 of Set 11 | wladyslawowo
# Processing Record 1 of Set 12 | dibaya
# City not found. Skipping...
# Processing Record 2 of Set 12 | constitucion
# Processing Record 3 of Set 12 | kenai
# Processing Record 4 of Set 12 | fare
# Processing Record 5 of Set 12 | ayagoz
# Processing Record 6 of Set 12 | mount gambier
# Processing Record 7 of Set 12 | ellon
# Processing Record 8 of Set 12 | chissamba
# Processing Record 9 of Set 12 | gunnedah
# Processing Record 10 of Set 12 | shizunai
# Processing Record 11 of Set 12 | tomatlan
# Processing Record 12 of Set 12 | olga
# Processing Record 13 of Set 12 | moose factory
# Processing Record 14 of Set 12 | la palma
# Processing Record 15 of Set 12 | surgut
# Processing Record 16 of Set 12 | malpe
# Processing Record 17 of Set 12 | dakar
# Processing Record 18 of Set 12 | dolgoye
# Processing Record 19 of Set 12 | erzin
# Processing Record 20 of Set 12 | zvishavane
# Processing Record 21 of Set 12 | bambanglipuro
# Processing Record 22 of Set 12 | mabaruma
# Processing Record 23 of Set 12 | thinadhoo
# Processing Record 24 of Set 12 | manowa
# Processing Record 25 of Set 12 | conde
# Processing Record 26 of Set 12 | presidencia roque saenz pena
# Processing Record 27 of Set 12 | pechory
# Processing Record 28 of Set 12 | buraydah
# Processing Record 29 of Set 12 | sinnamary
# Processing Record 30 of Set 12 | zlatoustovsk
# City not found. Skipping...
# Processing Record 31 of Set 12 | saint simons
# Processing Record 32 of Set 12 | seymchan
# Processing Record 33 of Set 12 | bojnurd
# Processing Record 34 of Set 12 | rocha
# Processing Record 35 of Set 12 | chulman
# Processing Record 36 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 37 of Set 12 | trincomalee
# Processing Record 38 of Set 12 | rincon
# Processing Record 39 of Set 12 | manzhouli
# Processing Record 40 of Set 12 | bushehr
# Processing Record 41 of Set 12 | dunedin
# Processing Record 42 of Set 12 | leshukonskoye
# Processing Record 43 of Set 12 | belmonte
# Processing Record 44 of Set 12 | san vicente
# Processing Record 45 of Set 12 | chokurdakh
# Processing Record 46 of Set 12 | klaksvik
# Processing Record 47 of Set 12 | karasuyama
# Processing Record 48 of Set 12 | vangaindrano
# Processing Record 49 of Set 12 | mokrousovo
# Processing Record 50 of Set 12 | dapitan
# Processing Record 1 of Set 13 | seybaplaya
# Processing Record 2 of Set 13 | borovichi
# Processing Record 3 of Set 13 | opuwo
# Processing Record 4 of Set 13 | ariquemes
# Processing Record 5 of Set 13 | eyl
# Processing Record 6 of Set 13 | marystown
# Processing Record 7 of Set 13 | yumen
# Processing Record 8 of Set 13 | tilichiki
# Processing Record 9 of Set 13 | icatu
# Processing Record 10 of Set 13 | fushun
# Processing Record 11 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 12 of Set 13 | san francisco
# Processing Record 13 of Set 13 | seddon
# Processing Record 14 of Set 13 | daru
# Processing Record 15 of Set 13 | kaura namoda
# Processing Record 16 of Set 13 | kahului
# Processing Record 17 of Set 13 | poya
# Processing Record 18 of Set 13 | timbiqui
# Processing Record 19 of Set 13 | gimli
# Processing Record 20 of Set 13 | camacha
# Processing Record 21 of Set 13 | san cristobal
# Processing Record 22 of Set 13 | polunochnoye
# Processing Record 23 of Set 13 | farim
# Processing Record 24 of Set 13 | damghan
# Processing Record 25 of Set 13 | tieli
# Processing Record 26 of Set 13 | kapit
# Processing Record 27 of Set 13 | khormuj
# City not found. Skipping...
# Processing Record 28 of Set 13 | la ronge
# Processing Record 29 of Set 13 | santiago del estero
# Processing Record 30 of Set 13 | teknaf
# Processing Record 31 of Set 13 | kawalu
# Processing Record 32 of Set 13 | torbay
# Processing Record 33 of Set 13 | nishihara
# Processing Record 34 of Set 13 | perth
# Processing Record 35 of Set 13 | esil
# Processing Record 36 of Set 13 | kerman
# Processing Record 37 of Set 13 | mandalgovi
# Processing Record 38 of Set 13 | hammerfest
# Processing Record 39 of Set 13 | mirnyy
# Processing Record 40 of Set 13 | ahipara
# Processing Record 41 of Set 13 | yinchuan
# Processing Record 42 of Set 13 | tuatapere
# Processing Record 43 of Set 13 | york
# Processing Record 44 of Set 13 | steinfurt
# Processing Record 45 of Set 13 | cockburn town
# Processing Record 46 of Set 13 | lethem
# Processing Record 47 of Set 13 | lermontovka
# Processing Record 48 of Set 13 | esna
# Processing Record 49 of Set 13 | paragominas
# Processing Record 50 of Set 13 | half moon bay
# Processing Record 1 of Set 14 | ladario
# Processing Record 2 of Set 14 | garoua
# Processing Record 3 of Set 14 | lincoln
# Processing Record 4 of Set 14 | parabel
# Processing Record 5 of Set 14 | joshimath
# Processing Record 6 of Set 14 | novoyegoryevskoye
# City not found. Skipping...
# Processing Record 7 of Set 14 | zlatoust
# Processing Record 8 of Set 14 | petatlan
# Processing Record 9 of Set 14 | bogorodskoye
# Processing Record 10 of Set 14 | seoul
# Processing Record 11 of Set 14 | de-kastri
# Processing Record 12 of Set 14 | trinidad
# Processing Record 13 of Set 14 | krasyliv
# Processing Record 14 of Set 14 | collie
# Processing Record 15 of Set 14 | ketchikan
# Processing Record 16 of Set 14 | sayyan
# Processing Record 17 of Set 14 | turtkul
# City not found. Skipping...
# Processing Record 18 of Set 14 | magadan
# Processing Record 19 of Set 14 | puri
# Processing Record 20 of Set 14 | tongchuan
# Processing Record 21 of Set 14 | balakovo
# Processing Record 22 of Set 14 | knyaze-volkonskoye
# Processing Record 23 of Set 14 | san jeronimo
# Processing Record 24 of Set 14 | mezokeresztes
# Processing Record 25 of Set 14 | westport
# Processing Record 26 of Set 14 | yeppoon
# Processing Record 27 of Set 14 | acajutla
# Processing Record 28 of Set 14 | duldurga
# Processing Record 29 of Set 14 | beaverlodge
# Processing Record 30 of Set 14 | vila nova de milfontes
# Processing Record 31 of Set 14 | sistranda
# Processing Record 32 of Set 14 | santa maria
# Processing Record 33 of Set 14 | mariinskiy posad
# Processing Record 34 of Set 14 | cherskiy
# Processing Record 35 of Set 14 | colares
# Processing Record 36 of Set 14 | okha
# Processing Record 37 of Set 14 | pundaguitan
# Processing Record 38 of Set 14 | kupang
# Processing Record 39 of Set 14 | mwinilunga
# Processing Record 40 of Set 14 | jian
# Processing Record 41 of Set 14 | parit buntar
# Processing Record 42 of Set 14 | morehead
# Processing Record 43 of Set 14 | vanino
# Processing Record 44 of Set 14 | pyay
# Processing Record 45 of Set 14 | porbandar
# Processing Record 46 of Set 14 | jardim
# Processing Record 47 of Set 14 | bowen
# Processing Record 48 of Set 14 | turukhansk
# Processing Record 49 of Set 14 | ponta delgada
# Processing Record 50 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 1 of Set 15 | ilebo
# Processing Record 2 of Set 15 | pindushi
# Processing Record 3 of Set 15 | guerrero negro
# Processing Record 4 of Set 15 | vanderhoof
# Processing Record 5 of Set 15 | assisi
# Processing Record 6 of Set 15 | zharkent
# Processing Record 7 of Set 15 | mayumba
# Processing Record 8 of Set 15 | arkhipo-osipovka
# Processing Record 9 of Set 15 | mae sai
# Processing Record 10 of Set 15 | ijaki
# City not found. Skipping...
# Processing Record 11 of Set 15 | ca mau
# Processing Record 12 of Set 15 | bilibino
# Processing Record 13 of Set 15 | yaan
# Processing Record 14 of Set 15 | juifang
# City not found. Skipping...
# Processing Record 15 of Set 15 | lixourion
# Processing Record 16 of Set 15 | chingirlau
# Processing Record 17 of Set 15 | sosnovo-ozerskoye
# Processing Record 18 of Set 15 | dauriya
# Processing Record 19 of Set 15 | katsiveli
# City not found. Skipping...
# Processing Record 20 of Set 15 | dong hoi
# Processing Record 21 of Set 15 | ambovombe
# Processing Record 22 of Set 15 | miandrivazo
# Processing Record 23 of Set 15 | odlabari
# Processing Record 24 of Set 15 | karratha
# Processing Record 25 of Set 15 | tonder
# Processing Record 26 of Set 15 | balkanabat
# Processing Record 27 of Set 15 | alipur
# Processing Record 28 of Set 15 | benjamin constant
# Processing Record 29 of Set 15 | wagar
# Processing Record 30 of Set 15 | vigrestad
# Processing Record 31 of Set 15 | ponnani
# Processing Record 32 of Set 15 | jackson
# Processing Record 33 of Set 15 | morden
# Processing Record 34 of Set 15 | atbasar
# Processing Record 35 of Set 15 | bom jesus
# Processing Record 36 of Set 15 | jasper
# Processing Record 37 of Set 15 | thunder bay
# Processing Record 38 of Set 15 | sandwick
# Processing Record 39 of Set 15 | baruun-urt
# Processing Record 40 of Set 15 | zielona gora
# Processing Record 41 of Set 15 | zarubino
# Processing Record 42 of Set 15 | newark
# Processing Record 43 of Set 15 | ochakiv
# Processing Record 44 of Set 15 | rio gallegos
# Processing Record 45 of Set 15 | takoradi
# Processing Record 46 of Set 15 | porto nacional
# Processing Record 47 of Set 15 | shimanovsk
# Processing Record 48 of Set 15 | krasnoborsk
# Processing Record 49 of Set 15 | upington
# Processing Record 50 of Set 15 | sapao
# City not found. Skipping...
# Processing Record 1 of Set 16 | pampa
# Processing Record 2 of Set 16 | presque isle
# Processing Record 3 of Set 16 | lingsugur
# Processing Record 4 of Set 16 | unterageri
# Processing Record 5 of Set 16 | fallon
# Processing Record 6 of Set 16 | bukachacha
# Processing Record 7 of Set 16 | vila
# Processing Record 8 of Set 16 | bairiki
# Processing Record 9 of Set 16 | kulhudhuffushi
# Processing Record 10 of Set 16 | oranjemund
# Processing Record 11 of Set 16 | bulawayo
# Processing Record 12 of Set 16 | ayer tawar
# Processing Record 13 of Set 16 | kedrovyy
# Processing Record 14 of Set 16 | rawlins
# Processing Record 15 of Set 16 | port augusta
# Processing Record 16 of Set 16 | doaba
# Processing Record 17 of Set 16 | tessalit
# Processing Record 18 of Set 16 | xichang
# Processing Record 19 of Set 16 | saint anthony
# Processing Record 20 of Set 16 | finnsnes
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Loop took 1094.08 seconds to complete.

# %%
city_data
# Out:
# [{'City': 'Hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 64.8,
#   'Humidity': 76,
#   'Cloudiness': 3,
#   'Wind Speed': 13.76,
#   'Country': 'ZA',
#   'Date': '2022-01-29 21:09:31',
#   'Weather Description': 'clear sky'},
#  {'City': 'Acapulco',
#   'Lat': 16.8634,
#   'Lng': -99.8901,
#   'Max Temp': 84.02,
#   'Humidity': 65,
#   'Cloudiness': 20,
#   'Wind Speed': 9.22,
#   'Country': 'MX',
#   'Date': '2022-01-29 21:09:32',
#   'Weather Description': 'few clouds'},
#  {'City': 'Tasiilaq',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 15.96,
#   'Humidity': 76,
#   'Cloudiness': 94,
#   'Wind Speed': 6.64,
#   'Country': 'GL',
#   'Date': '2022-01-29 21:09:32',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Cape Town',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 68.11,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 4,
#   'Country': 'ZA',
#   'Date': '2022-01-29 21:08:15',
#   'Weather Description': 'clear sky'},
#  {'City': 'Codrington',
#   'Lat': -38.2667,
#   'Lng': 141.9667,
#   'Max Temp': 63.81,
#   'Humidity': 82,
#   'Cloudiness': 80,
#   'Wind Speed': 6.33,
#   'Country': 'AU',
#   'Date': '2022-01-29 21:09:32',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 75.06,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Country': 'BR',
#   'Date': '2022-01-29 21:09:33',
#   'Weather Description': 'light rain'},
#  {'City': 'Gobabis',
#   'Lat': -22.45,
#   'Lng': 18.9667,
#   'Max Temp': 71.62,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 13.89,
#   'Country': 'NA',
#   'Date': '2022-01-29 21:09:33',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Mareeba',
#   'Lat': -17,
#   'Lng': 145.4333,
#   'Max Temp': 70.52,
#   'Humidity': 94,
#   'Cloudiness': 98,
#   'Wind Speed': 1.63,
#   'Country': 'AU',
#   'Date': '2022-01-29 21:09:33',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Rikitea',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 77.32,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 10.71,
#   'Country': 'PF',
#   'Date': '2022-01-29 21:09:33',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Veraval',
#   'Lat': 20.9,
#   'Lng': 70.3667,
#   'Max Temp': 67.03,
#   'Humidity': 43,
#   'Cloudiness': 3,
#   'Wind Speed': 7.96,
#   'Country': 'IN',
#   'Date': '2022-01-29 21:09:34',
#   'Weather Description': 'clear sky'},
#  {'City': 'Ondjiva',
#   'Lat': -17.0667,
#   'Lng': 15.7333,
#   'Max Temp': 72.59,
#   'Humidity': 71,
#   'Cloudiness': 96,
#   'Wind Speed': 8.08,
#   'Country': 'AO',
#   'Date': '2022-01-29 21:09:34',
#   'Weather Description': 'moderate rain'},
#  {'City': 'Pitimbu',
#   'Lat': -7.4706,
#   'Lng': -34.8086,
#   'Max Temp': 79.39,
#   'Humidity': 78,
#   'Cloudiness': 66,
#   'Wind Speed': 7.81,
#   'Country': 'BR',
#   'Date': '2022-01-29 21:09:34',
#   'Weather Description': 'broken clouds'},
#  {'City': 'San Pedro',
#   'Lat': 14.35,
#   'Lng': 121.0167,
#   'Max Temp': 79.36,
#   'Humidity': 90,
#   'Cloudiness': 3,
#   'Wind Speed': 3.04,
#   'Country': 'PH',
#   'Date': '2022-01-29 21:09:35',
#   'Weather Description': 'clear sky'},
#  {'City': 'Alibag',
#   'Lat': 18.6411,
#   'Lng': 72.8792,
#   'Max Temp': 71.67,
#   'Humidity': 62,
#   'Cloudiness': 2,
#   'Wind Speed': 4.56,
#   'Country': 'IN',
#   'Date': '2022-01-29 21:09:35',
#   'Weather Description': 'clear sky'},
#  {'City': 'Severo-Kurilsk',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 23.59,
#   'Humidity': 77,
#   'Cloudiness': 90,
#   'Wind Speed': 18.97,
#   'Country': 'RU',
#   'Date': '2022-01-29 21:09:35',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': 0.36,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 11.1,
#   'Country': 'GL',
#   'Date': '2022-01-29 21:09:36',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Villa Carlos Paz',
#   'Lat': -31.4241,
#   'Lng': -64.4978,
#   'Max Temp': 81.25,
#   'Humidity': 10,
#   'Cloudiness': 0,
#   'Wind Speed': 5.99,
#   'Country': 'AR',
#   'Date': '2022-01-29 21:09:36',
#   'Weather Description': 'clear sky'},
#  {'City': 'Hobart',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 62.02,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Country': 'AU',
#   'Date': '2022-01-29 21:09:36',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Margate',
#   'Lat': 51.3813,
#   'Lng': 1.3862,
#   'Max Temp': 48.31,
#   'Humidity': 67,
#   'Cloudiness': 45,
#   'Wind Speed': 8.99,
#   'Country': 'GB',
#   'Date': '2022-01-29 21:09:37',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Petropavlovsk-Kamchatskiy',
#   'Lat': 53.0452,
#   'Lng': 158.6483,
#   'Max Temp': 18.19,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 4.47,
#   'Country': 'RU',
#   'Date': '2022-01-29 21:09:37',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Copiapo',
#   'Lat': -27.3667,
#   'Lng': -70.3333,
#   'Max Temp': 69.49,
#   'Humidity': 43,
#   'Cloudiness': 0,
#   'Wind Speed': 10.02,
#   'Country': 'CL',
#   'Date': '2022-01-29 21:09:37',
#   'Weather Description': 'clear sky'},
#  {'City': 'Campbell River',
#   'Lat': 50.0163,
#   'Lng': -125.2446,
#   'Max Temp': 39.25,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 5.26,
#   'Country': 'CA',
#   'Date': '2022-01-29 21:09:37',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Usinsk',
#   'Lat': 65.9939,
#   'Lng': 57.5281,
#   'Max Temp': 12.15,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 19.42,
#   'Country': 'RU',
#   'Date': '2022-01-29 21:09:38',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Cap Malheureux',
#   'Lat': -19.9842,
#   'Lng': 57.6142,
#   'Max Temp': 79.47,
#   'Humidity': 74,
#   'Cloudiness': 87,
#   'Wind Speed': 3,
#   'Country': 'MU',
#   'Date': '2022-01-29 21:09:38',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Merrill',
#   'Lat': 45.1805,
#   'Lng': -89.6835,
#   'Max Temp': 22.8,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Date': '2022-01-29 21:09:38',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Tarpon Springs',
#   'Lat': 28.1461,
#   'Lng': -82.7568,
#   'Max Temp': 51.06,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Date': '2022-01-29 21:09:39',
#   'Weather Description': 'clear sky'},
#  {'City': 'Albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 15.37,
#   'Humidity': 61,
#   'Cloudiness': 100,
#   'Wind Speed': 7,
#   'Country': 'US',
#   'Date': '2022-01-29 21:09:39',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Yellowknife',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': -4.59,
#   'Humidity': 94,
#   'Cloudiness': 82,
#   'Wind Speed': 5.86,
#   'Country': 'CA',
#   'Date': '2022-01-29 21:06:24',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Upernavik',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 1.8,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 8.5,
#   'Country': 'GL',
#   'Date': '2022-01-29 21:05:36',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': -8.73,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 16.89,
#   'Country': 'CA',
#   'Date': '2022-01-29 21:09:40',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 53.71,
#   'Humidity': 54,
#   'Cloudiness': 75,
#   'Wind Speed': 17.27,
#   'Country': 'CL',
#   'Date': '2022-01-29 21:09:40',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Taboga',
#   'Lat': 46.2663,
#   'Lng': 13.1092,
#   'Max Temp': 36.88,
#   'Humidity': 66,
#   'Cloudiness': 31,
#   'Wind Speed': 3.58,
#   'Country': 'IT',
#   'Date': '2022-01-29 21:09:40',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Naliya',
#   'Lat': 23.2667,
#   'Lng': 68.8333,
#   'Max Temp': 63.59,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind Speed': 6.24,
#   'Country': 'IN',
#   'Date': '2022-01-29 21:09:41',
#   'Weather Description': 'clear sky'},
#  {'City': 'Ibra',
#   'Lat': 22.6906,
#   'Lng': 58.5334,
#   'Max Temp': 64.83,
#   'Humidity': 62,
#   'Cloudiness': 3,
#   'Wind Speed': 2.26,
#   'Country': 'OM',
#   'Date': '2022-01-29 21:09:41',
#   'Weather Description': 'clear sky'},
#  {'City': 'Khandyga',
#   'Lat': 62.6667,
#   'Lng': 135.6,
#   'Max Temp': -41.03,
#   'Humidity': 99,
#   'Cloudiness': 59,
#   'Wind Speed': 1.95,
#   'Country': 'RU',
#   'Date': '2022-01-29 21:09:41',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 80.87,
#   'Humidity': 67,
#   'Cloudiness': 89,
#   'Wind Speed': 3.11,
#   'Country': 'MV',
#   'Date': '2022-01-29 21:09:41',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Victoria',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 60.24,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 11.43,
#   'Country': 'HK',
#   'Date': '2022-01-29 21:05:24',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Auki',
#   'Lat': -8.7676,
#   'Lng': 160.7034,
#   'Max Temp': 80.1,
#   'Humidity': 86,
#   'Cloudiness': 99,
#   'Wind Speed': 5.73,
#   'Country': 'SB',
#   'Date': '2022-01-29 21:09:42',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Keti Bandar',
#   'Lat': 24.1447,
#   'Lng': 67.4497,
#   'Max Temp': 69.17,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 8.9,
#   'Country': 'PK',
#   'Date': '2022-01-29 21:09:42',
#   'Weather Description': 'clear sky'},
#  {'City': 'Lompoc',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 68.85,
#   'Humidity': 39,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Date': '2022-01-29 21:08:06',
#   'Weather Description': 'clear sky'},
#  {'City': 'Dunmore East',
#   'Lat': 52.1514,
#   'Lng': -6.9861,
#   'Max Temp': 44.33,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'IE',
#   'Date': '2022-01-29 21:09:43',
#   'Weather Description': 'clear sky'},
#  {'City': 'Alberdi',
#   'Lat': -32.8899,
#   'Lng': -60.6906,
#   'Max Temp': 90.03,
#   'Humidity': 37,
#   'Cloudiness': 0,
#   'Wind Speed': 3,
#   'Country': 'AR',
#   'Date': '2022-01-29 21:09:43',
#   'Weather Description': 'clear sky'},
#  {'City': 'Bengkulu',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 75.88,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 4.25,
#   'Country': 'ID',
#   'Date': '2022-01-29 21:09:43',
#   'Weather Description': 'heavy intensity rain'},
#  {'City': 'Thompson',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': -0.15,
#   'Humidity': 84,
#   'Cloudiness': 94,
#   'Wind Speed': 3.78,
#   'Country': 'CA',
#   'Date': '2022-01-29 21:08:58',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Mamlyutka',
#   'Lat': 54.9375,
#   'Lng': 68.5394,
#   'Max Temp': 3.09,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 6.44,
#   'Country': 'KZ',
#   'Date': '2022-01-29 21:10:44',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Pasighat',
#   'Lat': 28.0667,
#   'Lng': 95.3333,
#   'Max Temp': 50.11,
#   'Humidity': 68,
#   'Cloudiness': 1,
#   'Wind Speed': 3.65,
#   'Country': 'IN',
#   'Date': '2022-01-29 21:10:44',
#   'Weather Description': 'clear sky'},
#  {'City': 'Hilo',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 78.53,
#   'Humidity': 55,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Date': '2022-01-29 21:10:44',
#   'Weather Description': 'few clouds'},
#  {'City': 'Kaitangata',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 56.39,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 4.25,
#   'Country': 'NZ',
#   'Date': '2022-01-29 21:08:11',
#   'Weather Description': 'light rain'},
#  {'City': 'Vestmannaeyjar',
#   'Lat': 63.4427,
#   'Lng': -20.2734,
#   'Max Temp': 40.37,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 18.05,
#   'Country': 'IS',
#   'Date': '2022-01-29 21:10:45',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Flin Flon',
#   'Lat': 54.7682,
#   'Lng': -101.865,
#   'Max Temp': 6.84,
#   'Humidity': 84,
#   'Cloudiness': 95,
#   'Wind Speed': 0.92,
#   'Country': 'CA',
#   'Date': '2022-01-29 21:10:45',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Srednekolymsk',
#   'Lat': 67.45,
#   'Lng': 153.6833,
#   'Max Temp': -24.95,
#   'Humidity': 100,
#   'Cloudiness': 93,
#   'Wind Speed': 4.14,
#   'Country': 'RU',
#   'Date': '2022-01-29 21:10:45',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 64.27,
#   'Humidity': 72,
#   'Cloudiness': 5,
#   'Wind Speed': 10.98,
#   'Country': 'ZA',
#   'Date': '2022-01-29 21:10:46',
#   'Weather Description': 'clear sky'},
#  {'City': 'Luderitz',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 67.57,
#   'Humidity': 80,
#   'Cloudiness': 73,
#   'Wind Speed': 8.81,
#   'Country': 'NA',
#   'Date': '2022-01-29 21:10:46',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Mataura',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 57.36,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 2.57,
#   'Country': 'NZ',
#   'Date': '2022-01-29 21:10:46',
#   'Weather Description': 'light rain'},
#  {'City': 'Coquimbo',
#   'Lat': -29.9533,
#   'Lng': -71.3436,
#   'Max Temp': 67.73,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Country': 'CL',
#   'Date': '2022-01-29 21:10:46',
#   'Weather Description': 'clear sky'},
#  {'City': 'Ilulissat',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': 12.22,
#   'Humidity': 57,
#   'Cloudiness': 100,
#   'Wind Speed': 16.11,
#   'Country': 'GL',
#   'Date': '2022-01-29 21:10:47',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Barrow',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': -7.58,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 11.5,
#   'Country': 'US',
#   'Date': '2022-01-29 21:10:36',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Kazachinskoye',
#   'Lat': 57.6953,
#   'Lng': 93.2761,
#   'Max Temp': -3.82,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 3.09,
#   'Country': 'RU',
#   'Date': '2022-01-29 21:10:47',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 67.05,
#   'Humidity': 91,
#   'Cloudiness': 5,
#   'Wind Speed': 14.34,
#   'Country': 'AU',
#   'Date': '2022-01-29 21:08:36',
#   'Weather Description': 'clear sky'},
#  {'City': 'Georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 81.9,
#   'Humidity': 84,
#   'Cloudiness': 20,
#   'Wind Speed': 0,
#   'Country': 'MY',
#   'Date': '2022-01-29 21:09:38',
#   'Weather Description': 'few clouds'},
#  {'City': 'Mount Isa',
#   'Lat': -20.7333,
#   'Lng': 139.5,
#   'Max Temp': 74.97,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'AU',
#   'Date': '2022-01-29 21:09:47',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Narsaq',
#   'Lat': 60.9167,
#   'Lng': -46.05,
#   'Max Temp': 14.22,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 2.48,
#   'Country': 'GL',
#   'Date': '2022-01-29 21:10:48',
#   'Weather Description': 'light snow'},
#  {'City': 'Horqueta',
#   'Lat': -23.3428,
#   'Lng': -57.0597,
#   'Max Temp': 94.96,
#   'Humidity': 26,
#   'Cloudiness': 1,
#   'Wind Speed': 8.01,
#   'Country': 'PY',
#   'Date': '2022-01-29 21:10:48',
#   'Weather Description': 'clear sky'},
#  {'City': 'Khatanga',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': -4.34,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 5.53,
#   'Country': 'RU',
#   'Date': '2022-01-29 21:10:48',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'San Patricio',
#   'Lat': 28.017,
#   'Lng': -97.5169,
#   'Max Temp': 67.01,
#   'Humidity': 25,
#   'Cloudiness': 54,
#   'Wind Speed': 5.39,
#   'Country': 'US',
#   'Date': '2022-01-29 21:10:49',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Tawang',
#   'Lat': 27.5833,
#   'Lng': 91.8667,
#   'Max Temp': 22.89,
#   'Humidity': 72,
#   'Cloudiness': 32,
#   'Wind Speed': 6.11,
#   'Country': 'IN',
#   'Date': '2022-01-29 21:10:49',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Tulnici',
#   'Lat': 45.9167,
#   'Lng': 26.6667,
#   'Max Temp': 27.77,
#   'Humidity': 76,
#   'Cloudiness': 48,
#   'Wind Speed': 9.04,
#   'Country': 'RO',
#   'Date': '2022-01-29 21:10:49',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Carnarvon',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 77.07,
#   'Humidity': 88,
#   'Cloudiness': 84,
#   'Wind Speed': 10.36,
#   'Country': 'AU',
#   'Date': '2022-01-29 21:10:50',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Mar Del Plata',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 84.22,
#   'Humidity': 90,
#   'Cloudiness': 0,
#   'Wind Speed': 18.01,
#   'Country': 'AR',
#   'Date': '2022-01-29 21:10:50',
#   'Weather Description': 'clear sky'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 51.94,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 3.13,
#   'Country': 'AR',
#   'Date': '2022-01-29 21:10:50',
#   'Weather Description': 'light rain'},
#  {'City': 'Portland',
#   'Lat': 45.5234,
#   'Lng': -122.6762,
#   'Max Temp': 52.56,
#   'Humidity': 54,
#   'Cloudiness': 20,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Date': '2022-01-29 21:09:10',
#   'Weather Description': 'few clouds'},
#  {'City': 'Chapais',
#   'Lat': 49.7834,
#   'Lng': -74.8492,
#   'Max Temp': -0.33,
#   'Humidity': 88,
#   'Cloudiness': 6,
#   'Wind Speed': 2.3,
#   'Country': 'CA',
#   'Date': '2022-01-29 21:10:51',
#   'Weather Description': 'clear sky'},
#  {'City': 'Komsomolskiy',
#   'Lat': 40.4272,
#   'Lng': 71.7189,
#   'Max Temp': 36.32,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 0,
#   'Country': 'UZ',
#   'Date': '2022-01-29 21:10:51',
#   'Weather Description': 'fog'},
#  {'City': 'Muscat',
#   'Lat': 23.6139,
#   'Lng': 58.5922,
#   'Max Temp': 68.02,
#   'Humidity': 63,
#   'Cloudiness': 1,
#   'Wind Speed': 4,
#   'Country': 'OM',
#   'Date': '2022-01-29 21:10:51',
#   'Weather Description': 'clear sky'},
#  {'City': 'Saskylakh',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': -21.84,
#   'Humidity': 100,
#   'Cloudiness': 99,
#   'Wind Speed': 3.44,
#   'Country': 'RU',
#   'Date': '2022-01-29 21:10:52',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Byron Bay',
#   'Lat': -28.65,
#   'Lng': 153.6167,
#   'Max Temp': 73.87,
#   'Humidity': 81,
#   'Cloudiness': 61,
#   'Wind Speed': 8.77,
#   'Country': 'AU',
#   'Date': '2022-01-29 21:10:52',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Jacareacanga',
#   'Lat': -6.2222,
#   'Lng': -57.7528,
#   'Max Temp': 73.54,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 2.28,
#   'Country': 'BR',
#   'Date': '2022-01-29 21:10:52',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'New Norfolk',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 61.66,
#   'Humidity': 61,
#   'Cloudiness': 23,
#   'Wind Speed': 1.01,
#   'Country': 'AU',
#   'Date': '2022-01-29 21:10:53',
#   'Weather Description': 'few clouds'},
#  {'City': 'Hambantota',
#   'Lat': 6.1241,
#   'Lng': 81.1185,
#   'Max Temp': 77.95,
#   'Humidity': 82,
#   'Cloudiness': 73,
#   'Wind Speed': 6.8,
#   'Country': 'LK',
#   'Date': '2022-01-29 21:10:53',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Port Blair',
#   'Lat': 11.6667,
#   'Lng': 92.75,
#   'Max Temp': 75.92,
#   'Humidity': 79,
#   'Cloudiness': 66,
#   'Wind Speed': 8.75,
#   'Country': 'IN',
#   'Date': '2022-01-29 21:10:53',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 81.46,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 16.84,
#   'Country': 'TO',
#   'Date': '2022-01-29 21:08:06',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Clyde River',
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Max Temp': -12.71,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 3.4,
#   'Country': 'CA',
#   'Date': '2022-01-29 21:10:54',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Hamilton',
#   'Lat': 39.1834,
#   'Lng': -84.5333,
#   'Max Temp': 26.2,
#   'Humidity': 58,
#   'Cloudiness': 40,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Date': '2022-01-29 21:06:29',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Grand Gaube',
#   'Lat': -20.0064,
#   'Lng': 57.6608,
#   'Max Temp': 79.38,
#   'Humidity': 74,
#   'Cloudiness': 90,
#   'Wind Speed': 3,
#   'Country': 'MU',
#   'Date': '2022-01-29 21:10:54',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Berlevag',
#   'Lat': 70.8578,
#   'Lng': 29.0864,
#   'Max Temp': 19.4,
#   'Humidity': 79,
#   'Cloudiness': 98,
#   'Wind Speed': 5.84,
#   'Country': 'NO',
#   'Date': '2022-01-29 21:10:54',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Cidreira',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 73.67,
#   'Humidity': 58,
#   'Cloudiness': 56,
#   'Wind Speed': 12.64,
#   'Country': 'BR',
#   'Date': '2022-01-29 21:11:55',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Bontang',
#   'Lat': 0.1333,
#   'Lng': 117.5,
#   'Max Temp': 78.46,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 1.34,
#   'Country': 'ID',
#   'Date': '2022-01-29 21:11:55',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Sidi Ali',
#   'Lat': 36.0998,
#   'Lng': 0.4206,
#   'Max Temp': 51.03,
#   'Humidity': 43,
#   'Cloudiness': 0,
#   'Wind Speed': 9.19,
#   'Country': 'DZ',
#   'Date': '2022-01-29 21:11:56',
#   'Weather Description': 'clear sky'},
#  {'City': 'Port Alfred',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 70.18,
#   'Humidity': 83,
#   'Cloudiness': 46,
#   'Wind Speed': 12.37,
#   'Country': 'ZA',
#   'Date': '2022-01-29 21:09:17',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Semnan',
#   'Lat': 35.5729,
#   'Lng': 53.3971,
#   'Max Temp': 34.68,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 2.68,
#   'Country': 'IR',
#   'Date': '2022-01-29 21:11:56',
#   'Weather Description': 'clear sky'},
#  {'City': 'Cabo San Lucas',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 80.62,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 7,
#   'Country': 'MX',
#   'Date': '2022-01-29 21:11:56',
#   'Weather Description': 'clear sky'},
#  {'City': 'Paka',
#   'Lat': 4.6374,
#   'Lng': 103.4368,
#   'Max Temp': 74.05,
#   'Humidity': 87,
#   'Cloudiness': 51,
#   'Wind Speed': 3.18,
#   'Country': 'MY',
#   'Date': '2022-01-29 21:08:09',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Saldanha',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp': 65.03,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 16.91,
#   'Country': 'ZA',
#   'Date': '2022-01-29 21:11:57',
#   'Weather Description': 'clear sky'},
#  {'City': 'Bukama',
#   'Lat': -9.2,
#   'Lng': 25.85,
#   'Max Temp': 69.67,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 0.98,
#   'Country': 'CD',
#   'Date': '2022-01-29 21:11:57',
#   'Weather Description': 'moderate rain'},
#  {'City': 'Egvekinot',
#   'Lat': 66.3167,
#   'Lng': -179.1667,
#   'Max Temp': -6.32,
#   'Humidity': 65,
#   'Cloudiness': 12,
#   'Wind Speed': 2.59,
#   'Country': 'RU',
#   'Date': '2022-01-29 21:11:36',
#   'Weather Description': 'few clouds'},
#  {'City': 'Mbini',
#   'Lat': 1.574,
#   'Lng': 9.6134,
#   'Max Temp': 80.74,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 6.76,
#   'Country': 'GQ',
#   'Date': '2022-01-29 21:11:57',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Langsa',
#   'Lat': 4.4683,
#   'Lng': 97.9683,
#   'Max Temp': 73.6,
#   'Humidity': 96,
#   'Cloudiness': 46,
#   'Wind Speed': 3.09,
#   'Country': 'ID',
#   'Date': '2022-01-29 21:11:58',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Belyy Yar',
#   'Lat': 53.6039,
#   'Lng': 91.3903,
#   'Max Temp': -20.31,
#   'Humidity': 76,
#   'Cloudiness': 40,
#   'Wind Speed': 0,
#   'Country': 'RU',
#   'Date': '2022-01-29 21:11:58',
#   'Weather Description': 'smoke'},
#  {'City': 'Kinablangan',
#   'Lat': 7.6947,
#   'Lng': 126.5503,
#   'Max Temp': 75.94,
#   'Humidity': 84,
#   'Cloudiness': 95,
#   'Wind Speed': 3.89,
#   'Country': 'PH',
#   'Date': '2022-01-29 21:11:58',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Inuvik',
#   'Lat': 68.3499,
#   'Lng': -133.7218,
#   'Max Temp': -21.6,
#   'Humidity': 95,
#   'Cloudiness': 92,
#   'Wind Speed': 4.83,
#   'Country': 'CA',
#   'Date': '2022-01-29 21:11:59',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Aklavik',
#   'Lat': 68.2191,
#   'Lng': -135.0107,
#   'Max Temp': -19.21,
#   'Humidity': 90,
#   'Cloudiness': 91,
#   'Wind Speed': 4.94,
#   'Country': 'CA',
#   'Date': '2022-01-29 21:11:59',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Imeni Stepana Razina',
#   'Lat': 54.8932,
#   'Lng': 44.2963,
#   'Max Temp': 19.74,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 4.54,
#   'Country': 'RU',
#   'Date': '2022-01-29 21:11:59',
#   'Weather Description': 'light snow'},
#  {'City': 'Provideniya',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': 2.66,
#   'Humidity': 86,
#   'Cloudiness': 4,
#   'Wind Speed': 5.01,
#   'Country': 'RU',
#   'Date': '2022-01-29 21:11:59',
#   'Weather Description': 'clear sky'},
#  {'City': 'Castro',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 60.17,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 6.11,
#   'Country': 'BR',
#   'Date': '2022-01-29 21:08:09',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Pevek',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': -18.06,
#   'Humidity': 99,
#   'Cloudiness': 82,
#   'Wind Speed': 3.44,
#   'Country': 'RU',
#   'Date': '2022-01-29 21:12:00',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Nemuro',
#   'Lat': 43.3236,
#   'Lng': 145.575,
#   'Max Temp': 17.29,
#   'Humidity': 76,
#   'Cloudiness': 57,
#   'Wind Speed': 17.16,
#   'Country': 'JP',
#   'Date': '2022-01-29 21:12:00',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 58.39,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 6.85,
#   'Country': 'NZ',
#   'Date': '2022-01-29 21:12:00',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Strezhevoy',
#   'Lat': 60.7333,
#   'Lng': 77.5889,
#   'Max Temp': -2.02,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 4.45,
#   'Country': 'RU',
#   'Date': '2022-01-29 21:12:01',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Itagiba',
#   'Lat': -14.2836,
#   'Lng': -39.8428,
#   'Max Temp': 76.66,
#   'Humidity': 88,
#   'Cloudiness': 93,
#   'Wind Speed': 2.42,
#   'Country': 'BR',
#   'Date': '2022-01-29 21:12:01',
#   'Weather Description': 'light rain'},
#  {'City': 'Lagos',
#   'Lat': 6.5833,
#   'Lng': 3.75,
#   'Max Temp': 75.79,
#   'Humidity': 58,
#   'Cloudiness': 90,
#   'Wind Speed': 1.77,
#   'Country': 'NG',
#   'Date': '2022-01-29 21:10:54',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Isangel',
#   'Lat': -19.55,
#   'Lng': 169.2667,
#   'Max Temp': 80.17,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 15.5,
#   'Country': 'VU',
#   'Date': '2022-01-29 21:12:02',
#   'Weather Description': 'heavy intensity rain'},
#  {'City': 'Kavieng',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 82.18,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 7.36,
#   'Country': 'PG',
#   'Date': '2022-01-29 21:11:02',
#   'Weather Description': 'light rain'},
#  {'City': 'Umm Kaddadah',
#   'Lat': 13.6017,
#   'Lng': 26.6876,
#   'Max Temp': 57.61,
#   'Humidity': 18,
#   'Cloudiness': 6,
#   'Wind Speed': 13.82,
#   'Country': 'SD',
#   'Date': '2022-01-29 21:12:02',
#   'Weather Description': 'clear sky'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 82.36,
#   'Humidity': 71,
#   'Cloudiness': 28,
#   'Wind Speed': 9.35,
#   'Country': 'EC',
#   'Date': '2022-01-29 21:12:02',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Lebu',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 64.4,
#   'Humidity': 76,
#   'Cloudiness': 2,
#   'Wind Speed': 10.96,
#   'Country': 'CL',
#   'Date': '2022-01-29 21:12:03',
#   'Weather Description': 'clear sky'},
#  {'City': 'Laguna',
#   'Lat': 38.421,
#   'Lng': -121.4238,
#   'Max Temp': 66.04,
#   'Humidity': 49,
#   'Cloudiness': 0,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Date': '2022-01-29 21:12:03',
#   'Weather Description': 'clear sky'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 59.4,
#   'Humidity': 67,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Country': 'PT',
#   'Date': '2022-01-29 21:12:03',
#   'Weather Description': 'few clouds'},
#  {'City': 'Iqaluit',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': -16.46,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 3.8,
#   'Country': 'CA',
#   'Date': '2022-01-29 21:12:04',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Butaritari',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 82.11,
#   'Humidity': 76,
#   'Cloudiness': 25,
#   'Wind Speed': 19.89,
#   'Country': 'KI',
#   'Date': '2022-01-29 21:07:39',
#   'Weather Description': 'light rain'},
#  {'City': 'Kloulklubed',
#   'Lat': 7.0419,
#   'Lng': 134.2556,
#   'Max Temp': 75.7,
#   'Humidity': 77,
#   'Cloudiness': 69,
#   'Wind Speed': 8.37,
#   'Country': 'PW',
#   'Date': '2022-01-29 21:12:04',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Bilma',
#   'Lat': 18.6853,
#   'Lng': 12.9164,
#   'Max Temp': 61.03,
#   'Humidity': 18,
#   'Cloudiness': 1,
#   'Wind Speed': 10.92,
#   'Country': 'NE',
#   'Date': '2022-01-29 21:12:05',
#   'Weather Description': 'clear sky'},
#  {'City': 'Norman Wells',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': -18.67,
#   'Humidity': 98,
#   'Cloudiness': 36,
#   'Wind Speed': 2.86,
#   'Country': 'CA',
#   'Date': '2022-01-29 21:09:32',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Souillac',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 79.36,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 12.35,
#   'Country': 'MU',
#   'Date': '2022-01-29 21:12:05',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Ban Nahin',
#   'Lat': 18.2418,
#   'Lng': 104.2122,
#   'Max Temp': 68.04,
#   'Humidity': 82,
#   'Cloudiness': 52,
#   'Wind Speed': 4.47,
#   'Country': 'LA',
#   'Date': '2022-01-29 21:12:05',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Longyearbyen',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 8.44,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 14.97,
#   'Country': 'SJ',
#   'Date': '2022-01-29 21:12:06',
#   'Weather Description': 'clear sky'},
#  {'City': 'Avarua',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 82.45,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 9.22,
#   'Country': 'CK',
#   'Date': '2022-01-29 21:12:06',
#   'Weather Description': 'few clouds'},
#  {'City': 'Puerto Quijarro',
#   'Lat': -17.7833,
#   'Lng': -57.7667,
#   'Max Temp': 80.08,
#   'Humidity': 81,
#   'Cloudiness': 88,
#   'Wind Speed': 2.53,
#   'Country': 'BO',
#   'Date': '2022-01-29 21:11:10',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Pervomayskoye',
#   'Lat': 43.919,
#   'Lng': 46.7102,
#   'Max Temp': 36.66,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 11.18,
#   'Country': 'RU',
#   'Date': '2022-01-29 21:13:06',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'San Rafael',
#   'Lat': -34.6177,
#   'Lng': -68.3301,
#   'Max Temp': 90.95,
#   'Humidity': 24,
#   'Cloudiness': 0,
#   'Wind Speed': 16.93,
#   'Country': 'AR',
#   'Date': '2022-01-29 21:13:07',
#   'Weather Description': 'clear sky'},
#  {'City': 'Taltal',
#   'Lat': -25.4,
#   'Lng': -70.4833,
#   'Max Temp': 68.79,
#   'Humidity': 69,
#   'Cloudiness': 8,
#   'Wind Speed': 7.67,
#   'Country': 'CL',
#   'Date': '2022-01-29 21:13:07',
#   'Weather Description': 'clear sky'},
#  {'City': 'Champerico',
#   'Lat': 14.3,
#   'Lng': -91.9167,
#   'Max Temp': 90.77,
#   'Humidity': 63,
#   'Cloudiness': 3,
#   'Wind Speed': 12.73,
#   'Country': 'GT',
#   'Date': '2022-01-29 21:13:07',
#   'Weather Description': 'clear sky'},
#  {'City': 'Mokolo',
#   'Lat': 10.7398,
#   'Lng': 13.8019,
#   'Max Temp': 63,
#   'Humidity': 26,
#   'Cloudiness': 100,
#   'Wind Speed': 6.33,
#   'Country': 'CM',
#   'Date': '2022-01-29 21:13:08',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Gayny',
#   'Lat': 60.3071,
#   'Lng': 54.3241,
#   'Max Temp': 6.4,
#   'Humidity': 98,
#   'Cloudiness': 95,
#   'Wind Speed': 3.58,
#   'Country': 'RU',
#   'Date': '2022-01-29 21:13:08',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Quatre Cocos',
#   'Lat': -20.2078,
#   'Lng': 57.7625,
#   'Max Temp': 79.09,
#   'Humidity': 71,
#   'Cloudiness': 97,
#   'Wind Speed': 14.32,
#   'Country': 'MU',
#   'Date': '2022-01-29 21:13:08',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Roslyakovo',
#   'Lat': 69.043,
#   'Lng': 33.1991,
#   'Max Temp': 14.72,
#   'Humidity': 100,
#   'Cloudiness': 92,
#   'Wind Speed': 1.68,
#   'Country': 'RU',
#   'Date': '2022-01-29 21:13:08',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Tahe',
#   'Lat': 52.3333,
#   'Lng': 124.7333,
#   'Max Temp': -1.66,
#   'Humidity': 79,
#   'Cloudiness': 16,
#   'Wind Speed': 7.74,
#   'Country': 'CN',
#   'Date': '2022-01-29 21:13:09',
#   'Weather Description': 'few clouds'},
#  {'City': 'Saint George',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 64.87,
#   'Humidity': 15,
#   'Cloudiness': 0,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Date': '2022-01-29 21:12:20',
#   'Weather Description': 'clear sky'},
#  {'City': 'Te Anau',
#   'Lat': -45.4167,
#   'Lng': 167.7167,
#   'Max Temp': 57.67,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 1.41,
#   'Country': 'NZ',
#   'Date': '2022-01-29 21:10:21',
#   'Weather Description': 'light rain'},
#  {'City': 'Chicama',
#   'Lat': -7.8447,
#   'Lng': -79.1469,
#   'Max Temp': 68.54,
#   'Humidity': 62,
#   'Cloudiness': 81,
#   'Wind Speed': 10.83,
#   'Country': 'PE',
#   'Date': '2022-01-29 21:13:09',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Sitka',
#   'Lat': 57.0531,
#   'Lng': -135.33,
#   'Max Temp': 37.29,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 14.97,
#   'Country': 'US',
#   'Date': '2022-01-29 21:13:10',
#   'Weather Description': 'moderate rain'},
#  {'City': 'Akhmeta',
#   'Lat': 42.0311,
#   'Lng': 45.2075,
#   'Max Temp': 34.32,
#   'Humidity': 56,
#   'Cloudiness': 27,
#   'Wind Speed': 5.28,
#   'Country': 'GE',
#   'Date': '2022-01-29 21:13:10',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Marawi',
#   'Lat': 7.9986,
#   'Lng': 124.2928,
#   'Max Temp': 66.65,
#   'Humidity': 94,
#   'Cloudiness': 86,
#   'Wind Speed': 0.76,
#   'Country': 'PH',
#   'Date': '2022-01-29 21:13:10',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 77.72,
#   'Humidity': 75,
#   'Cloudiness': 18,
#   'Wind Speed': 13.67,
#   'Country': 'PF',
#   'Date': '2022-01-29 21:12:29',
#   'Weather Description': 'few clouds'},
#  {'City': 'Kapaa',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 80.58,
#   'Humidity': 72,
#   'Cloudiness': 20,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Date': '2022-01-29 21:13:11',
#   'Weather Description': 'few clouds'},
#  {'City': 'Murmashi',
#   'Lat': 68.8154,
#   'Lng': 32.8115,
#   'Max Temp': 14.41,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 0,
#   'Country': 'RU',
#   'Date': '2022-01-29 21:13:11',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Chuy',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 74.12,
#   'Humidity': 61,
#   'Cloudiness': 18,
#   'Wind Speed': 11.32,
#   'Country': 'UY',
#   'Date': '2022-01-29 21:13:11',
#   'Weather Description': 'few clouds'},
#  {'City': 'Comodoro Rivadavia',
#   'Lat': -45.8667,
#   'Lng': -67.5,
#   'Max Temp': 87.66,
#   'Humidity': 8,
#   'Cloudiness': 0,
#   'Wind Speed': 23.02,
#   'Country': 'AR',
#   'Date': '2022-01-29 21:13:12',
#   'Weather Description': 'clear sky'},
#  {'City': 'Maragogi',
#   'Lat': -9.0122,
#   'Lng': -35.2225,
#   'Max Temp': 76.41,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 6.02,
#   'Country': 'BR',
#   'Date': '2022-01-29 21:13:12',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Batemans Bay',
#   'Lat': -35.7167,
#   'Lng': 150.1833,
#   'Max Temp': 75.2,
#   'Humidity': 95,
#   'Cloudiness': 96,
#   'Wind Speed': 2.19,
#   'Country': 'AU',
#   'Date': '2022-01-29 21:13:12',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Suntar',
#   'Lat': 62.1444,
#   'Lng': 117.6319,
#   'Max Temp': -17.23,
#   'Humidity': 97,
#   'Cloudiness': 56,
#   'Wind Speed': 4.83,
#   'Country': 'RU',
#   'Date': '2022-01-29 21:13:13',
#   'Weather Description': 'broken clouds'},
#  {'City': 'San Luis',
#   'Lat': -33.295,
#   'Lng': -66.3356,
#   'Max Temp': 88.5,
#   'Humidity': 23,
#   'Cloudiness': 0,
#   'Wind Speed': 3.62,
#   'Country': 'AR',
#   'Date': '2022-01-29 21:10:05',
#   'Weather Description': 'clear sky'},
#  {'City': 'Asyut',
#   'Lat': 27.181,
#   'Lng': 31.1837,
#   'Max Temp': 50.52,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 7.11,
#   'Country': 'EG',
#   'Date': '2022-01-29 21:13:13',
#   'Weather Description': 'clear sky'},
#  {'City': 'Urdoma',
#   'Lat': 61.7533,
#   'Lng': 48.5442,
#   'Max Temp': 15.48,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 7.29,
#   'Country': 'RU',
#   'Date': '2022-01-29 21:13:13',
#   'Weather Description': 'light snow'},
#  {'City': 'Jinchang',
#   'Lat': 38.4953,
#   'Lng': 102.1739,
#   'Max Temp': 17.24,
#   'Humidity': 58,
#   'Cloudiness': 26,
#   'Wind Speed': 11.12,
#   'Country': 'CN',
#   'Date': '2022-01-29 21:13:14',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Beringovskiy',
#   'Lat': 63.05,
#   'Lng': 179.3167,
#   'Max Temp': -11.65,
#   'Humidity': 100,
#   'Cloudiness': 97,
#   'Wind Speed': 3.38,
#   'Country': 'RU',
#   'Date': '2022-01-29 21:10:22',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Hobyo',
#   'Lat': 5.3505,
#   'Lng': 48.5268,
#   'Max Temp': 76.84,
#   'Humidity': 78,
#   'Cloudiness': 17,
#   'Wind Speed': 23.15,
#   'Country': 'SO',
#   'Date': '2022-01-29 21:13:14',
#   'Weather Description': 'few clouds'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 76.59,
#   'Humidity': 85,
#   'Cloudiness': 55,
#   'Wind Speed': 9.06,
#   'Country': 'RE',
#   'Date': '2022-01-29 21:11:04',
#   'Weather Description': 'light rain'},
#  {'City': 'Necochea',
#   'Lat': -38.5473,
#   'Lng': -58.7368,
#   'Max Temp': 90.03,
#   'Humidity': 40,
#   'Cloudiness': 1,
#   'Wind Speed': 18.07,
#   'Country': 'AR',
#   'Date': '2022-01-29 21:13:14',
#   'Weather Description': 'clear sky'},
#  {'City': 'Santo Antonio Do Ica',
#   'Lat': -3.1022,
#   'Lng': -67.9397,
#   'Max Temp': 92.73,
#   'Humidity': 46,
#   'Cloudiness': 73,
#   'Wind Speed': 2.95,
#   'Country': 'BR',
#   'Date': '2022-01-29 21:09:18',
#   'Weather Description': 'light rain'},
#  {'City': 'Marshall',
#   'Lat': 34.3834,
#   'Lng': -86.3333,
#   'Max Temp': 39.96,
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Date': '2022-01-29 21:09:39',
#   'Weather Description': 'clear sky'},
#  {'City': 'Sao Cristovao',
#   'Lat': -11.0147,
#   'Lng': -37.2064,
#   'Max Temp': 80.51,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'BR',
#   'Date': '2022-01-29 21:13:15',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Ende',
#   'Lat': -8.8432,
#   'Lng': 121.6623,
#   'Max Temp': 77.97,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 6.2,
#   'Country': 'ID',
#   'Date': '2022-01-29 21:13:15',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Mehamn',
#   'Lat': 71.0357,
#   'Lng': 27.8492,
#   'Max Temp': 19.35,
#   'Humidity': 86,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'NO',
#   'Date': '2022-01-29 21:13:15',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Auch',
#   'Lat': 43.65,
#   'Lng': 0.5833,
#   'Max Temp': 39.25,
#   'Humidity': 87,
#   'Cloudiness': 2,
#   'Wind Speed': 1.01,
#   'Country': 'FR',
#   'Date': '2022-01-29 21:13:16',
#   'Weather Description': 'clear sky'},
#  {'City': 'Santa Lucia',
#   'Lat': 27.9117,
#   'Lng': -15.5407,
#   'Max Temp': 56.77,
#   'Humidity': 55,
#   'Cloudiness': 100,
#   'Wind Speed': 10.36,
#   'Country': 'ES',
#   'Date': '2022-01-29 21:11:46',
#   'Weather Description': 'haze'},
#  {'City': 'Kupino',
#   'Lat': 54.3663,
#   'Lng': 77.2981,
#   'Max Temp': 1.51,
#   'Humidity': 89,
#   'Cloudiness': 27,
#   'Wind Speed': 9.35,
#   'Country': 'RU',
#   'Date': '2022-01-29 21:13:16',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Nakamura',
#   'Lat': 32.9833,
#   'Lng': 132.9333,
#   'Max Temp': 39.04,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 3.76,
#   'Country': 'JP',
#   'Date': '2022-01-29 21:13:17',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 16.09,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 5.01,
#   'Country': 'US',
#   'Date': '2022-01-29 21:10:42',
#   'Weather Description': 'clear sky'},
#  {'City': 'Vila Franca Do Campo',
#   'Lat': 37.7167,
#   'Lng': -25.4333,
#   'Max Temp': 59.2,
#   'Humidity': 74,
#   'Cloudiness': 58,
#   'Wind Speed': 8.97,
#   'Country': 'PT',
#   'Date': '2022-01-29 21:10:34',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Bend',
#   'Lat': 44.0582,
#   'Lng': -121.3153,
#   'Max Temp': 52.38,
#   'Humidity': 37,
#   'Cloudiness': 0,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Date': '2022-01-29 21:09:15',
#   'Weather Description': 'clear sky'},
#  {'City': 'Borogontsy',
#   'Lat': 62.6683,
#   'Lng': 131.1683,
#   'Max Temp': -37.17,
#   'Humidity': 100,
#   'Cloudiness': 69,
#   'Wind Speed': 1.83,
#   'Country': 'RU',
#   'Date': '2022-01-29 21:13:17',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Pangai',
#   'Lat': -19.8,
#   'Lng': -174.35,
#   'Max Temp': 82.09,
#   'Humidity': 76,
#   'Cloudiness': 83,
#   'Wind Speed': 13.2,
#   'Country': 'TO',
#   'Date': '2022-01-29 21:13:17',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Pokaran',
#   'Lat': 26.9167,
#   'Lng': 71.9167,
#   'Max Temp': 61.25,
#   'Humidity': 18,
#   'Cloudiness': 0,
#   'Wind Speed': 4.68,
#   'Country': 'IN',
#   'Date': '2022-01-29 21:13:18',
#   'Weather Description': 'clear sky'},
#  {'City': 'Mildura',
#   'Lat': -34.2,
#   'Lng': 142.15,
#   'Max Temp': 69.76,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'AU',
#   'Date': '2022-01-29 21:13:18',
#   'Weather Description': 'clear sky'},
#  {'City': 'Hasaki',
#   'Lat': 35.7333,
#   'Lng': 140.8333,
#   'Max Temp': 27,
#   'Humidity': 61,
#   'Cloudiness': 65,
#   'Wind Speed': 19.8,
#   'Country': 'JP',
#   'Date': '2022-01-29 21:14:18',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Port-Gentil',
#   'Lat': -0.7193,
#   'Lng': 8.7815,
#   'Max Temp': 81.41,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 9.82,
#   'Country': 'GA',
#   'Date': '2022-01-29 21:14:19',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Touros',
#   'Lat': -5.1989,
#   'Lng': -35.4608,
#   'Max Temp': 79.7,
#   'Humidity': 77,
#   'Cloudiness': 95,
#   'Wind Speed': 10.31,
#   'Country': 'BR',
#   'Date': '2022-01-29 21:14:19',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Okhotsk',
#   'Lat': 59.3833,
#   'Lng': 143.3,
#   'Max Temp': 13.48,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 14.61,
#   'Country': 'RU',
#   'Date': '2022-01-29 21:14:19',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Rawson',
#   'Lat': -43.3002,
#   'Lng': -65.1023,
#   'Max Temp': 83.1,
#   'Humidity': 32,
#   'Cloudiness': 62,
#   'Wind Speed': 7.85,
#   'Country': 'AR',
#   'Date': '2022-01-29 21:14:20',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Greenwood',
#   'Lat': 34.1668,
#   'Lng': -82.1165,
#   'Max Temp': 43.48,
#   'Humidity': 15,
#   'Cloudiness': 0,
#   'Wind Speed': 7,
#   'Country': 'US',
#   'Date': '2022-01-29 21:14:20',
#   'Weather Description': 'clear sky'},
#  {'City': 'Am Timan',
#   'Lat': 11.0297,
#   'Lng': 20.2827,
#   'Max Temp': 75.49,
#   'Humidity': 18,
#   'Cloudiness': 41,
#   'Wind Speed': 7.56,
#   'Country': 'TD',
#   'Date': '2022-01-29 21:14:20',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Goderich',
#   'Lat': 43.7501,
#   'Lng': -81.7165,
#   'Max Temp': 17.91,
#   'Humidity': 79,
#   'Cloudiness': 89,
#   'Wind Speed': 6.67,
#   'Country': 'CA',
#   'Date': '2022-01-29 21:13:16',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Bambous Virieux',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 79.21,
#   'Humidity': 70,
#   'Cloudiness': 99,
#   'Wind Speed': 13.65,
#   'Country': 'MU',
#   'Date': '2022-01-29 21:10:17',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Vardo',
#   'Lat': 70.3705,
#   'Lng': 31.1107,
#   'Max Temp': 21.31,
#   'Humidity': 78,
#   'Cloudiness': 93,
#   'Wind Speed': 0.96,
#   'Country': 'NO',
#   'Date': '2022-01-29 21:14:21',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Ponta Do Sol',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 65.03,
#   'Humidity': 67,
#   'Cloudiness': 25,
#   'Wind Speed': 5.06,
#   'Country': 'PT',
#   'Date': '2022-01-29 21:10:24',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Marsa Matruh',
#   'Lat': 31.3525,
#   'Lng': 27.2453,
#   'Max Temp': 54.52,
#   'Humidity': 62,
#   'Cloudiness': 15,
#   'Wind Speed': 14.18,
#   'Country': 'EG',
#   'Date': '2022-01-29 21:14:21',
#   'Weather Description': 'few clouds'},
#  {'City': 'Emerald',
#   'Lat': -23.5333,
#   'Lng': 148.1667,
#   'Max Temp': 74.34,
#   'Humidity': 70,
#   'Cloudiness': 25,
#   'Wind Speed': 5.88,
#   'Country': 'AU',
#   'Date': '2022-01-29 21:11:07',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Goroka',
#   'Lat': -6.0834,
#   'Lng': 145.3873,
#   'Max Temp': 60.15,
#   'Humidity': 96,
#   'Cloudiness': 97,
#   'Wind Speed': 2.24,
#   'Country': 'PG',
#   'Date': '2022-01-29 21:14:22',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Kodiak',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 35.11,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 24.16,
#   'Country': 'US',
#   'Date': '2022-01-29 21:10:36',
#   'Weather Description': 'clear sky'},
#  {'City': 'East London',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 72.01,
#   'Humidity': 80,
#   'Cloudiness': 83,
#   'Wind Speed': 10.71,
#   'Country': 'ZA',
#   'Date': '2022-01-29 21:10:36',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Port Elizabeth',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 67.1,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 8.7,
#   'Country': 'ZA',
#   'Date': '2022-01-29 21:14:22',
#   'Weather Description': 'clear sky'},
#  {'City': 'Dikson',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 3.61,
#   'Humidity': 93,
#   'Cloudiness': 99,
#   'Wind Speed': 21.88,
#   'Country': 'RU',
#   'Date': '2022-01-29 21:14:22',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Sarangani',
#   'Lat': 5.4033,
#   'Lng': 125.4636,
#   'Max Temp': 80.71,
#   'Humidity': 75,
#   'Cloudiness': 86,
#   'Wind Speed': 7.43,
#   'Country': 'PH',
#   'Date': '2022-01-29 21:14:23',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Darnah',
#   'Lat': 32.767,
#   'Lng': 22.6367,
#   'Max Temp': 52.36,
#   'Humidity': 65,
#   'Cloudiness': 53,
#   'Wind Speed': 23.4,
#   'Country': 'LY',
#   'Date': '2022-01-29 21:14:23',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Vao',
#   'Lat': -22.6667,
#   'Lng': 167.4833,
#   'Max Temp': 78.66,
#   'Humidity': 87,
#   'Cloudiness': 95,
#   'Wind Speed': 11.79,
#   'Country': 'NC',
#   'Date': '2022-01-29 21:14:23',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Atoyac',
#   'Lat': 20.0167,
#   'Lng': -103.5333,
#   'Max Temp': 79.16,
#   'Humidity': 27,
#   'Cloudiness': 7,
#   'Wind Speed': 2.66,
#   'Country': 'MX',
#   'Date': '2022-01-29 21:14:24',
#   'Weather Description': 'clear sky'},
#  {'City': 'Kashi',
#   'Lat': 39.4547,
#   'Lng': 75.9797,
#   'Max Temp': 24.22,
#   'Humidity': 55,
#   'Cloudiness': 25,
#   'Wind Speed': 1.66,
#   'Country': 'CN',
#   'Date': '2022-01-29 21:14:24',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Sao Sepe',
#   'Lat': -30.1606,
#   'Lng': -53.5653,
#   'Max Temp': 85.55,
#   'Humidity': 29,
#   'Cloudiness': 0,
#   'Wind Speed': 11.59,
#   'Country': 'BR',
#   'Date': '2022-01-29 21:14:24',
#   'Weather Description': 'clear sky'},
#  {'City': 'Havelock',
#   'Lat': 34.8791,
#   'Lng': -76.9013,
#   'Max Temp': 39.18,
#   'Humidity': 52,
#   'Cloudiness': 40,
#   'Wind Speed': 14,
#   'Country': 'US',
#   'Date': '2022-01-29 21:14:25',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Yangcun',
#   'Lat': 39.3639,
#   'Lng': 117.0603,
#   'Max Temp': 19.38,
#   'Humidity': 42,
#   'Cloudiness': 0,
#   'Wind Speed': 0.96,
#   'Country': 'CN',
#   'Date': '2022-01-29 21:14:25',
#   'Weather Description': 'clear sky'},
#  {'City': 'Namibe',
#   'Lat': -15.1961,
#   'Lng': 12.1522,
#   'Max Temp': 72.28,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 6.69,
#   'Country': 'AO',
#   'Date': '2022-01-29 21:14:25',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Staryy Nadym',
#   'Lat': 65.6118,
#   'Lng': 72.6842,
#   'Max Temp': -8.07,
#   'Humidity': 96,
#   'Cloudiness': 99,
#   'Wind Speed': 8.9,
#   'Country': 'RU',
#   'Date': '2022-01-29 21:14:26',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Namtsy',
#   'Lat': 62.7161,
#   'Lng': 129.6658,
#   'Max Temp': -30.89,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 1.74,
#   'Country': 'RU',
#   'Date': '2022-01-29 21:14:26',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Nikolskoye',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 27.72,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 14.97,
#   'Country': 'RU',
#   'Date': '2022-01-29 21:14:26',
#   'Weather Description': 'light snow'},
#  {'City': 'Bubaque',
#   'Lat': 11.2833,
#   'Lng': -15.8333,
#   'Max Temp': 78.44,
#   'Humidity': 72,
#   'Cloudiness': 92,
#   'Wind Speed': 21.16,
#   'Country': 'GW',
#   'Date': '2022-01-29 21:14:27',
# ...
#   'Country': 'AU',
#   'Date': '2022-01-29 21:25:26',
#   'Weather Description': 'clear sky'},
#  {'City': 'Turukhansk',
#   'Lat': 65.8167,
#   'Lng': 87.9833,
#   'Max Temp': 2.05,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 10.02,
#   'Country': 'RU',
#   'Date': '2022-01-29 21:25:26',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Ponta Delgada',
#   'Lat': 37.7333,
#   'Lng': -25.6667,
#   'Max Temp': 58.5,
#   'Humidity': 77,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'PT',
#   'Date': '2022-01-29 21:25:26',
#   'Weather Description': 'few clouds'},
#  {'City': 'Ilebo',
#   'Lat': -4.3167,
#   'Lng': 20.5833,
#   'Max Temp': 72.39,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 0.81,
#   'Country': 'CD',
#   'Date': '2022-01-29 21:26:27',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Pindushi',
#   'Lat': 62.9152,
#   'Lng': 34.58,
#   'Max Temp': 12.92,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 9.91,
#   'Country': 'RU',
#   'Date': '2022-01-29 21:26:27',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Guerrero Negro',
#   'Lat': 27.9769,
#   'Lng': -114.0611,
#   'Max Temp': 71.19,
#   'Humidity': 29,
#   'Cloudiness': 8,
#   'Wind Speed': 12.35,
#   'Country': 'MX',
#   'Date': '2022-01-29 21:26:25',
#   'Weather Description': 'clear sky'},
#  {'City': 'Vanderhoof',
#   'Lat': 54.0166,
#   'Lng': -124.0198,
#   'Max Temp': 33.03,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 2.93,
#   'Country': 'CA',
#   'Date': '2022-01-29 21:26:27',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Assisi',
#   'Lat': 43.0691,
#   'Lng': 12.6165,
#   'Max Temp': 40.75,
#   'Humidity': 59,
#   'Cloudiness': 30,
#   'Wind Speed': 3,
#   'Country': 'IT',
#   'Date': '2022-01-29 21:26:28',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Zharkent',
#   'Lat': 44.1628,
#   'Lng': 80,
#   'Max Temp': 25.88,
#   'Humidity': 56,
#   'Cloudiness': 100,
#   'Wind Speed': 1.05,
#   'Country': 'KZ',
#   'Date': '2022-01-29 21:26:28',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Mayumba',
#   'Lat': -3.432,
#   'Lng': 10.6554,
#   'Max Temp': 77.54,
#   'Humidity': 90,
#   'Cloudiness': 72,
#   'Wind Speed': 3.2,
#   'Country': 'GA',
#   'Date': '2022-01-29 21:26:28',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Arkhipo-Osipovka',
#   'Lat': 44.37,
#   'Lng': 38.52,
#   'Max Temp': 41.09,
#   'Humidity': 78,
#   'Cloudiness': 43,
#   'Wind Speed': 15.08,
#   'Country': 'RU',
#   'Date': '2022-01-29 21:26:29',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Mae Sai',
#   'Lat': 20.4335,
#   'Lng': 99.8762,
#   'Max Temp': 56.89,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 2.59,
#   'Country': 'TH',
#   'Date': '2022-01-29 21:26:29',
#   'Weather Description': 'clear sky'},
#  {'City': 'Ca Mau',
#   'Lat': 9.1769,
#   'Lng': 105.15,
#   'Max Temp': 73.49,
#   'Humidity': 86,
#   'Cloudiness': 45,
#   'Wind Speed': 2.28,
#   'Country': 'VN',
#   'Date': '2022-01-29 21:26:29',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Bilibino',
#   'Lat': 68.0546,
#   'Lng': 166.4372,
#   'Max Temp': -4.36,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 2.8,
#   'Country': 'RU',
#   'Date': '2022-01-29 21:26:30',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Yaan',
#   'Lat': 7.3833,
#   'Lng': 8.5667,
#   'Max Temp': 80.96,
#   'Humidity': 15,
#   'Cloudiness': 70,
#   'Wind Speed': 7.2,
#   'Country': 'NG',
#   'Date': '2022-01-29 21:26:30',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Lixourion',
#   'Lat': 38.2019,
#   'Lng': 20.4314,
#   'Max Temp': 47.5,
#   'Humidity': 65,
#   'Cloudiness': 14,
#   'Wind Speed': 16.24,
#   'Country': 'GR',
#   'Date': '2022-01-29 21:26:30',
#   'Weather Description': 'few clouds'},
#  {'City': 'Chingirlau',
#   'Lat': 51.095,
#   'Lng': 54.0814,
#   'Max Temp': 12.54,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 6.51,
#   'Country': 'KZ',
#   'Date': '2022-01-29 21:26:31',
#   'Weather Description': 'snow'},
#  {'City': 'Sosnovo-Ozerskoye',
#   'Lat': 52.5249,
#   'Lng': 111.5418,
#   'Max Temp': -27.36,
#   'Humidity': 100,
#   'Cloudiness': 92,
#   'Wind Speed': 2.06,
#   'Country': 'RU',
#   'Date': '2022-01-29 21:26:31',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Dauriya',
#   'Lat': 49.9333,
#   'Lng': 116.8667,
#   'Max Temp': -20.61,
#   'Humidity': 99,
#   'Cloudiness': 32,
#   'Wind Speed': 1.28,
#   'Country': 'RU',
#   'Date': '2022-01-29 21:26:31',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Dong Hoi',
#   'Lat': 17.4833,
#   'Lng': 106.6,
#   'Max Temp': 71.13,
#   'Humidity': 94,
#   'Cloudiness': 98,
#   'Wind Speed': 6.46,
#   'Country': 'VN',
#   'Date': '2022-01-29 21:26:32',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Ambovombe',
#   'Lat': -25.1667,
#   'Lng': 46.0833,
#   'Max Temp': 72.36,
#   'Humidity': 87,
#   'Cloudiness': 4,
#   'Wind Speed': 10.4,
#   'Country': 'MG',
#   'Date': '2022-01-29 21:26:32',
#   'Weather Description': 'clear sky'},
#  {'City': 'Miandrivazo',
#   'Lat': -19.5167,
#   'Lng': 45.4667,
#   'Max Temp': 78.67,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 2.04,
#   'Country': 'MG',
#   'Date': '2022-01-29 21:26:32',
#   'Weather Description': 'clear sky'},
#  {'City': 'Odlabari',
#   'Lat': 26.8333,
#   'Lng': 88.6167,
#   'Max Temp': 54.37,
#   'Humidity': 66,
#   'Cloudiness': 14,
#   'Wind Speed': 2.93,
#   'Country': 'IN',
#   'Date': '2022-01-29 21:26:32',
#   'Weather Description': 'few clouds'},
#  {'City': 'Karratha',
#   'Lat': -20.7377,
#   'Lng': 116.8463,
#   'Max Temp': 80.83,
#   'Humidity': 62,
#   'Cloudiness': 75,
#   'Wind Speed': 14.7,
#   'Country': 'AU',
#   'Date': '2022-01-29 21:26:33',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Tonder',
#   'Lat': 54.9331,
#   'Lng': 8.8667,
#   'Max Temp': 44.6,
#   'Humidity': 81,
#   'Cloudiness': 86,
#   'Wind Speed': 13,
#   'Country': 'DK',
#   'Date': '2022-01-29 21:26:33',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Balkanabat',
#   'Lat': 39.5108,
#   'Lng': 54.3671,
#   'Max Temp': 41.5,
#   'Humidity': 61,
#   'Cloudiness': 6,
#   'Wind Speed': 5.06,
#   'Country': 'TM',
#   'Date': '2022-01-29 21:25:31',
#   'Weather Description': 'clear sky'},
#  {'City': 'Alipur',
#   'Lat': 29.3846,
#   'Lng': 70.9116,
#   'Max Temp': 56.52,
#   'Humidity': 30,
#   'Cloudiness': 48,
#   'Wind Speed': 6.69,
#   'Country': 'PK',
#   'Date': '2022-01-29 21:26:33',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Benjamin Constant',
#   'Lat': -4.3831,
#   'Lng': -70.0311,
#   'Max Temp': 91.53,
#   'Humidity': 55,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Country': 'BR',
#   'Date': '2022-01-29 21:26:34',
#   'Weather Description': 'few clouds'},
#  {'City': 'Wagar',
#   'Lat': 16.1525,
#   'Lng': 36.2032,
#   'Max Temp': 67.51,
#   'Humidity': 58,
#   'Cloudiness': 6,
#   'Wind Speed': 15.03,
#   'Country': 'SD',
#   'Date': '2022-01-29 21:26:34',
#   'Weather Description': 'clear sky'},
#  {'City': 'Vigrestad',
#   'Lat': 58.5667,
#   'Lng': 5.7,
#   'Max Temp': 42.58,
#   'Humidity': 73,
#   'Cloudiness': 72,
#   'Wind Speed': 46.75,
#   'Country': 'NO',
#   'Date': '2022-01-29 21:26:34',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Ponnani',
#   'Lat': 10.767,
#   'Lng': 75.9252,
#   'Max Temp': 79.92,
#   'Humidity': 72,
#   'Cloudiness': 40,
#   'Wind Speed': 3.53,
#   'Country': 'IN',
#   'Date': '2022-01-29 21:26:35',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Jackson',
#   'Lat': 42.4165,
#   'Lng': -122.8345,
#   'Max Temp': 61.84,
#   'Humidity': 41,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': '2022-01-29 21:23:44',
#   'Weather Description': 'clear sky'},
#  {'City': 'Morden',
#   'Lat': 49.1919,
#   'Lng': -98.1014,
#   'Max Temp': 19.78,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 16.11,
#   'Country': 'CA',
#   'Date': '2022-01-29 21:26:35',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Atbasar',
#   'Lat': 51.8,
#   'Lng': 68.3333,
#   'Max Temp': 11.12,
#   'Humidity': 96,
#   'Cloudiness': 97,
#   'Wind Speed': 4.81,
#   'Country': 'KZ',
#   'Date': '2022-01-29 21:26:35',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Bom Jesus',
#   'Lat': -9.0744,
#   'Lng': -44.3586,
#   'Max Temp': 74.48,
#   'Humidity': 86,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'BR',
#   'Date': '2022-01-29 21:26:36',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Jasper',
#   'Lat': 37.2001,
#   'Lng': -94.3502,
#   'Max Temp': 58.95,
#   'Humidity': 27,
#   'Cloudiness': 0,
#   'Wind Speed': 7,
#   'Country': 'US',
#   'Date': '2022-01-29 21:26:36',
#   'Weather Description': 'clear sky'},
#  {'City': 'Thunder Bay',
#   'Lat': 48.4001,
#   'Lng': -89.3168,
#   'Max Temp': 18.55,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 2.3,
#   'Country': 'CA',
#   'Date': '2022-01-29 21:26:36',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Sandwick',
#   'Lat': 60,
#   'Lng': -1.25,
#   'Max Temp': 39.02,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 29.93,
#   'Country': 'GB',
#   'Date': '2022-01-29 21:26:37',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Baruun-Urt',
#   'Lat': 46.6806,
#   'Lng': 113.2792,
#   'Max Temp': -8.36,
#   'Humidity': 88,
#   'Cloudiness': 16,
#   'Wind Speed': 2.33,
#   'Country': 'MN',
#   'Date': '2022-01-29 21:26:37',
#   'Weather Description': 'few clouds'},
#  {'City': 'Zielona Gora',
#   'Lat': 51.9355,
#   'Lng': 15.5064,
#   'Max Temp': 46.17,
#   'Humidity': 42,
#   'Cloudiness': 100,
#   'Wind Speed': 26.98,
#   'Country': 'PL',
#   'Date': '2022-01-29 21:26:37',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Zarubino',
#   'Lat': 42.63,
#   'Lng': 131.0922,
#   'Max Temp': 15.26,
#   'Humidity': 62,
#   'Cloudiness': 2,
#   'Wind Speed': 14.54,
#   'Country': 'RU',
#   'Date': '2022-01-29 21:26:37',
#   'Weather Description': 'clear sky'},
#  {'City': 'Newark',
#   'Lat': 40.7357,
#   'Lng': -74.1724,
#   'Max Temp': 20.91,
#   'Humidity': 62,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Country': 'US',
#   'Date': '2022-01-29 21:22:10',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Ochakiv',
#   'Lat': 46.6128,
#   'Lng': 31.5498,
#   'Max Temp': 24.94,
#   'Humidity': 75,
#   'Cloudiness': 40,
#   'Wind Speed': 12.01,
#   'Country': 'UA',
#   'Date': '2022-01-29 21:26:38',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Rio Gallegos',
#   'Lat': -51.6226,
#   'Lng': -69.2181,
#   'Max Temp': 48.25,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 20.71,
#   'Country': 'AR',
#   'Date': '2022-01-29 21:26:38',
#   'Weather Description': 'light rain'},
#  {'City': 'Takoradi',
#   'Lat': 4.8845,
#   'Lng': -1.7554,
#   'Max Temp': 80.04,
#   'Humidity': 85,
#   'Cloudiness': 12,
#   'Wind Speed': 5.86,
#   'Country': 'GH',
#   'Date': '2022-01-29 21:26:38',
#   'Weather Description': 'few clouds'},
#  {'City': 'Porto Nacional',
#   'Lat': -10.7081,
#   'Lng': -48.4172,
#   'Max Temp': 82.4,
#   'Humidity': 91,
#   'Cloudiness': 99,
#   'Wind Speed': 3.89,
#   'Country': 'BR',
#   'Date': '2022-01-29 21:26:39',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Shimanovsk',
#   'Lat': 52,
#   'Lng': 127.7,
#   'Max Temp': -4.97,
#   'Humidity': 90,
#   'Cloudiness': 21,
#   'Wind Speed': 7.7,
#   'Country': 'RU',
#   'Date': '2022-01-29 21:26:39',
#   'Weather Description': 'few clouds'},
#  {'City': 'Krasnoborsk',
#   'Lat': 61.5598,
#   'Lng': 45.934,
#   'Max Temp': 17.19,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 6.04,
#   'Country': 'RU',
#   'Date': '2022-01-29 21:26:39',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Upington',
#   'Lat': -28.4478,
#   'Lng': 21.2561,
#   'Max Temp': 84.58,
#   'Humidity': 32,
#   'Cloudiness': 99,
#   'Wind Speed': 9.22,
#   'Country': 'ZA',
#   'Date': '2022-01-29 21:26:40',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Pampa',
#   'Lat': 35.5362,
#   'Lng': -100.9599,
#   'Max Temp': 66.34,
#   'Humidity': 14,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Date': '2022-01-29 21:23:59',
#   'Weather Description': 'clear sky'},
#  {'City': 'Presque Isle',
#   'Lat': 46.6811,
#   'Lng': -68.0159,
#   'Max Temp': 4.03,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 5.99,
#   'Country': 'US',
#   'Date': '2022-01-29 21:27:40',
#   'Weather Description': 'heavy snow'},
#  {'City': 'Lingsugur',
#   'Lat': 16.1667,
#   'Lng': 76.5167,
#   'Max Temp': 67.68,
#   'Humidity': 35,
#   'Cloudiness': 3,
#   'Wind Speed': 4.5,
#   'Country': 'IN',
#   'Date': '2022-01-29 21:27:40',
#   'Weather Description': 'clear sky'},
#  {'City': 'Unterageri',
#   'Lat': 47.1364,
#   'Lng': 8.5853,
#   'Max Temp': 41.43,
#   'Humidity': 79,
#   'Cloudiness': 33,
#   'Wind Speed': 5.06,
#   'Country': 'CH',
#   'Date': '2022-01-29 21:27:41',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Fallon',
#   'Lat': 39.4735,
#   'Lng': -118.7774,
#   'Max Temp': 46.27,
#   'Humidity': 31,
#   'Cloudiness': 40,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Date': '2022-01-29 21:27:41',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Bukachacha',
#   'Lat': 52.9833,
#   'Lng': 116.9167,
#   'Max Temp': -13.2,
#   'Humidity': 96,
#   'Cloudiness': 5,
#   'Wind Speed': 4.09,
#   'Country': 'RU',
#   'Date': '2022-01-29 21:27:41',
#   'Weather Description': 'clear sky'},
#  {'City': 'Vila',
#   'Lat': 42.0304,
#   'Lng': -8.1588,
#   'Max Temp': 41.88,
#   'Humidity': 43,
#   'Cloudiness': 5,
#   'Wind Speed': 4.56,
#   'Country': 'PT',
#   'Date': '2022-01-29 21:27:42',
#   'Weather Description': 'clear sky'},
#  {'City': 'Bairiki',
#   'Lat': 1.3292,
#   'Lng': 172.9752,
#   'Max Temp': 84.2,
#   'Humidity': 79,
#   'Cloudiness': 20,
#   'Wind Speed': 9.22,
#   'Country': 'KI',
#   'Date': '2022-01-29 21:25:51',
#   'Weather Description': 'light rain'},
#  {'City': 'Kulhudhuffushi',
#   'Lat': 6.6221,
#   'Lng': 73.07,
#   'Max Temp': 81.82,
#   'Humidity': 76,
#   'Cloudiness': 70,
#   'Wind Speed': 18.97,
#   'Country': 'MV',
#   'Date': '2022-01-29 21:27:42',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Oranjemund',
#   'Lat': -28.55,
#   'Lng': 16.4333,
#   'Max Temp': 65.75,
#   'Humidity': 85,
#   'Cloudiness': 79,
#   'Wind Speed': 12.86,
#   'Country': 'NA',
#   'Date': '2022-01-29 21:27:42',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Bulawayo',
#   'Lat': -20.15,
#   'Lng': 28.5833,
#   'Max Temp': 64.94,
#   'Humidity': 92,
#   'Cloudiness': 94,
#   'Wind Speed': 15.66,
#   'Country': 'ZW',
#   'Date': '2022-01-29 21:27:43',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Ayer Tawar',
#   'Lat': 4.2954,
#   'Lng': 100.7548,
#   'Max Temp': 77.29,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 0,
#   'Country': 'MY',
#   'Date': '2022-01-29 21:27:43',
#   'Weather Description': 'few clouds'},
#  {'City': 'Kedrovyy',
#   'Lat': 56.1667,
#   'Lng': 91.8167,
#   'Max Temp': -12.14,
#   'Humidity': 98,
#   'Cloudiness': 44,
#   'Wind Speed': 3.71,
#   'Country': 'RU',
#   'Date': '2022-01-29 21:27:43',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Rawlins',
#   'Lat': 41.7911,
#   'Lng': -107.2387,
#   'Max Temp': 41.22,
#   'Humidity': 22,
#   'Cloudiness': 0,
#   'Wind Speed': 14.65,
#   'Country': 'US',
#   'Date': '2022-01-29 21:27:43',
#   'Weather Description': 'clear sky'},
#  {'City': 'Port Augusta',
#   'Lat': -32.5,
#   'Lng': 137.7667,
#   'Max Temp': 76.71,
#   'Humidity': 53,
#   'Cloudiness': 73,
#   'Wind Speed': 8.03,
#   'Country': 'AU',
#   'Date': '2022-01-29 21:27:44',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Doaba',
#   'Lat': 33.4244,
#   'Lng': 70.7364,
#   'Max Temp': 47.08,
#   'Humidity': 48,
#   'Cloudiness': 1,
#   'Wind Speed': 3.22,
#   'Country': 'PK',
#   'Date': '2022-01-29 21:27:44',
#   'Weather Description': 'clear sky'},
#  {'City': 'Tessalit',
#   'Lat': 20.1986,
#   'Lng': 1.0114,
#   'Max Temp': 69.21,
#   'Humidity': 14,
#   'Cloudiness': 72,
#   'Wind Speed': 12.71,
#   'Country': 'ML',
#   'Date': '2022-01-29 21:25:26',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Xichang',
#   'Lat': 27.8964,
#   'Lng': 102.2634,
#   'Max Temp': 35.98,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 2.01,
#   'Country': 'CN',
#   'Date': '2022-01-29 21:27:44',
#   'Weather Description': 'clear sky'},
#  {'City': 'Saint Anthony',
#   'Lat': 45.0205,
#   'Lng': -93.218,
#   'Max Temp': 28.94,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 5.01,
#   'Country': 'US',
#   'Date': '2022-01-29 21:27:45',
#   'Weather Description': 'clear sky'},
#  {'City': 'Finnsnes',
#   'Lat': 69.2296,
#   'Lng': 17.9811,
#   'Max Temp': 22.96,
#   'Humidity': 86,
#   'Cloudiness': 94,
#   'Wind Speed': 5.84,
#   'Country': 'NO',
#   'Date': '2022-01-29 21:27:45',
#   'Weather Description': 'overcast clouds'}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
new_order = ['City', 'Country', 'Date', 'Lat', 'Lng','Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Weather Description']
city_data_df = city_data_df[new_order]
city_data_df
# Out:
#               City Country                 Date      Lat       Lng  Max Temp  \
# 0         Hermanus      ZA  2022-01-29 21:09:31 -34.4187   19.2345     64.80
# 1         Acapulco      MX  2022-01-29 21:09:32  16.8634  -99.8901     84.02
# 2         Tasiilaq      GL  2022-01-29 21:09:32  65.6145  -37.6368     15.96
# 3        Cape Town      ZA  2022-01-29 21:08:15 -33.9258   18.4232     68.11
# 4       Codrington      AU  2022-01-29 21:09:32 -38.2667  141.9667     63.81
# ..             ...     ...                  ...      ...       ...       ...
# 697          Doaba      PK  2022-01-29 21:27:44  33.4244   70.7364     47.08
# 698       Tessalit      ML  2022-01-29 21:25:26  20.1986    1.0114     69.21
# 699        Xichang      CN  2022-01-29 21:27:44  27.8964  102.2634     35.98
# 700  Saint Anthony      US  2022-01-29 21:27:45  45.0205  -93.2180     28.94
# 701       Finnsnes      NO  2022-01-29 21:27:45  69.2296   17.9811     22.96
#
#      Humidity  Cloudiness  Wind Speed Weather Description
# 0          76           3       13.76           clear sky
# 1          65          20        9.22          few clouds
# 2          76          94        6.64     overcast clouds
# 3          72           0        4.00           clear sky
# 4          82          80        6.33       broken clouds
# ..        ...         ...         ...                 ...
# 697        48           1        3.22           clear sky
# 698        14          72       12.71       broken clouds
# 699        76           0        2.01           clear sky
# 700        61           0        5.01           clear sky
# 701        86          94        5.84     overcast clouds
#
# [702 rows x 10 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_vacation.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
